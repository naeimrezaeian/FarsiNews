# %%
import multiprocessing
import time
#import sys
import re

from gensim.models.doc2vec import Doc2Vec, TaggedDocument


from hazm import *

from __future__ import unicode_literals
import pandas as pd

from pandas import DataFrame

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.metrics import confusion_matrix, precision_score, recall_score, f1_score
from sklearn import metrics

from sklearn.naive_bayes import GaussianNB
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.manifold import TSNE

# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /anaconda2/lib/python2.7/site-packages/sklearn/ensemble/weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d

# %%
stopwords={'ات','اتفاقا','اجراست','احتمالا','احيانا','اخ','اختصارا'
               ,'اخر','اخرها','اخه','اخيرا','ادمهاست','اراسته','ارام','ارزانتر','ارزومندانه','ارنه','اره','از'
               ,'ازادانه','ازان','ازانجا','ازانجاكه','ازاين','ازاينرو','ازبه','ازجمله','ازروي','ازسر','ازش'
               ,'ازقبيل','ازلحاظ','ازنظر','ازو','ازيك','اساس','اساسا','اسان','اسانتر','اساني','است','استوارتر'
               ,'اسيبپذيرند','اش','اشان','اشتباها','اشفته','اشكار','اشكارا','اشكارتر','اشنايند','اصطلاحا','اصلا'
               ,'اصولا','اطلاعند','اغلب','افزودن','افسوس','افقي','اقل','اقلا','اقليت','اكتسابا','اكثر','اكثرا'
               ,'اكثريت','اكنون','الا','الاسف','الان','البته','الزاما','الظاهر','المقدور','الهي','الي','ام',
               'اما','امان','امرانه','امروز','امروزه','امسال','امشب','اميدوارم','اميدوارند','اميدواريم'
               ,'ان','انان','اناني','انجا','اند','اندك','اندكي','انرا','انشاالله','انقدر','انكس','انكه'
               ,'انم','انها','انهاست','انوقت','انچنان','انچه','انگار','انگاه','انگه','انگونه','اهان'
               ,'اهاي','او','اورد','اوردن','اوست','اول','اولا','اولش','اون','اونهمه','اوه','اويي','اي'
               ,'ايا','ايشان','ايم','اين','اينان','اينجا','اينجاست','اينجوري','اينرو','اينست','اينطور'
               ,'اينقدر','اينك','اينكه','اينها','اينهاست','اينهمه','اينو','اينچنين','اينگونه','اگاهانه'
               ,'اگر','اگرنه','اگرچه','اگه','ب','با','بااطمينان','باانكه','بااين','بااينكه','بار','باره'
               ,'بارها','بارهاوبارها','باز','بازانديشانه','بازهم','بازيگوشانه','باستثناي','باش','باشد'
               ,'باعلاقه','بالا','بالاتر','بالاخره','بالاخص','بالاست','بالاي','بالضرور','بالطبع','بالعكس',
               'بالقوه','بالله','بالنتيجه','بالنسبه','باهم','باوجود','باوجودانكه','باوجوداينكه',
               'باوجوديكه','باورند','بايد','بايستي','بتازگي','بتدريج','بتمامي','بجا','بجاي','بجز',
               'بخاطر','بخاطراينكه','بخردانه','بخشه','بخصوص','بخوبي','بد','بدان','بدانجا','بدانها',
               'بدبينانه','بدخواهانه','بدرستي','بدرشتي','بدلخواه','بدون','بدين','بدينجا','بدينسان',
               'بر','برا','براثر','براساس','براستي','بران','برانند','برانهاست','براي','برايت','برايش',
               'برايشان','برايم','برايمان','برحسب','برخلاف','برخوردارند','برخي','برداشتن','بردن','برروي',
               'برعكس','برغم','برمي','برنمي','برو','بروشني','برپا','بزعم','بزودي','بس','بسا','بسادگي','بسته',
               'بسختي','بسرعت','بسهولت','بسوي','بسي','بسيار','بسياري','بشان','بشدت','بصورت','بطبع','بطور',
               'بطوركلي','بطوري','بطوريكه','بعد','بعدا','بعداز','بعدازان','بعدازاين','بعدازظهر','بعدها',
               'بعدي','بعضي','بعضيشان','بعضيها','بعضيهاشان','بعضيهايشان','بعلاوه','بعيد','بفهمي','بقدري',
               'بكار','بكرات','بلادرنگ','بلافاصله','بلكه','بله','بمراتب','بموجب','بموقع','بنابراين','بنابه',
               'بناچار','بندرت','به','بهت','بهتر','بهرحال','بهش','بهيچ','بود','بودن','بوضوح','بويژه','بي',
               'بيرون','بيش','بيشتر','بين','بينابين','بيهوده','بيگمان','بپا','بگرمي','ت','تا','تاانجا'
               ,'تاانجاكه','تاانكه','تااينجا','تااينكه','تابه','تاجاييكه','تاحدودي','تاحدي','تازه','تازگي',
               'تاكنون','تاوقتي','تاوقتيكه','تحت','تدريج','تدريجا','تدريجي','تر','ترتيب','ترجيحا','ترديد',
               'ترند','تري','ترين','تصريحا','تعدادي','تعمدا','تفاوت','تفاوتند','تفنني','تقريبا','تك',
               'تلويحا','تمام','تماما','تمامشان','تمامي','تند','تنها','تنهايي','تنگاتنگ','تو','توسط',
               'تووما','توي','تويي','ث','ثالثا','ثاني','ثانيا','ج','جا','جاي','جايي','جبرگرايانه',
               'جدا','جدااز','جداازهم','جداگانه','جدي','جديدا','جرمزاست','جز','جزجز','جسورانه',
               'جلو','جلوتر','جلوي','جمع','جمعا','جمعي','جنابعالي','جنس','جهت','جور','جوري'
               ,'ح','حاشا','حاشاوكلا','حاشيه','حاضر','حاضرم','حاكيست','حال','حالا','حالكه',
               'حالي','حتما','حتي','حداقل','حداكثر','حدود','حرف','حسابي','حسابگرانه','حسب',
               'حضرتعالي','حقيرانه','حقيقتا','حكما','حكيمانه','حول','خ','خالص','خالصانه','خالي',
               'خام','خامسا','خب','خداحافظ','خداست','خداگونه','خردمندانه','خسته','خشمگين','خصمانه',
               'خصوصا','خلاقانه','خواسته','خواه','خواهد','خوب','خوبتر','خوبست','خوبي','خود','خوداند',
               'خوداگاهانه','خودبه','خودت','خودتان','خودتو','خودرا','خودش','خودشان','خودم','خودمان',
               'خودمختارانه','خودمو','خودنمايانه','خودي','خوش','خوشبختانه','خوشبينانه','خوشحال','خويش',
               'خويشتنم','خوگيرانه','خير','خيره','خيلي','د','دا','داام','دااما','داخل','دادن','دارا',
               'داراست','داراي','دارد','داشتن','داوطلبانه','دايم','دايما','دخترانه','دراثر','درازا',
               'درازاي','دران','دراين','درباب','درباره','دربدر','دربر','دربرابر','دربه','درتخت',
               'درثاني','درحال','درحالي','درحاليكه','دردكشان','درراستاي','درست','درسته','درشت',
               'درشتي','درصورتي','درصورتيكه','درطي','درعين','دركل','دركنار','درمجموع','درمقابل',
               'درمورد','درميان','درنتيجه','درنهايت','درهر','درهرحال','درهرصورت','درواقع','دريغ',
               'دريغا','درپي','دسته','دشمنيم','دشوار','دشوارتر','دقيق','دقيقا','دلخواه','دلخوش',
               'دلشاد','دم','دهد','دو','دوباره','دوتا','دوتادوتا','دور','دوراز','دورتر','دوساله',
               'دوستانه','دوم','دير','ديرت','ديرم','ديروز','ديروزبه','ديشب','ديوانه','ديوي','ديگر',
               'ديگران','ديگرتا','ديگري','ديگه','دگربار','دگرباره','دگرگون','ذ','ذاتا','ذالك',
               'ذيل','ذيلا','ر','را','رااز','رابه','راجع','راحت','راحتر','رادر','راسا','راست',
               'راستا','راستي','رسما','رشته','رغم','رفتارهاست','رنجند','رندانه','رهگشاست',
               'رو','رواست','روبرو','روبروست','روبه','روز','روزانه','روزبروز','روزمره',
               'روش','روشن','روشني','روي','رويش','رياكارانه','ريز','ريزان','ز','زد',
               'زدن','زده','زشت','زماني','زنند','زهي','زو','زود','زودتر','زودي',
               'زياد','زيادتر','زياده','زيبا','زيباتر','زير','زيرا','زيراكه',
               'زيركانه','زيرند','زيرچشمي','زين','س','سابقا','ساختن','ساده',
               'سادگي','سازان','سازهاست','سازي','سازگارانه','ساكنند','سالانه',
               'سالته','سالم','سالهاست','ساليانه','ساير','سايران','سايرين','ست'
               ,'سخت','سختتر','سخته','سر','سراسر','سرانجام','سراپا','سري','سريع'
               ,'سريعا','سعادتمندانه','سنگدلانه','سنگين','سه','سهوا','سوم','سياه',
               'سيخ','سپس','ش','شااالله','شاد','شادتر','شادمان','شاكله','شان','شاهدند'
               ,'شاهديم','شايد','شبانه','شبهاست','شتابان','شتابزده','شجاعانه','شخصا',
               'شد','شدت','شدن','شده','شديدا','شما','شماري','شماست','شمايند','شود',
               'شوراست','شوقم','شيرين','شيرينه','شيك','ص','صادقانه','صاف','صد','صدالبته',
               'صددرصد','صراحتا','صرفا','صريح','صريحا','صريحتر','صميمانه','صندوق','ض',
               'ضرورتا','ضعيف','ضعيفتر','ضمن','ضمنا','ط','طبعا','طبيعتا','طلبكارانه','طور',
               'طوري','طي','ظ','ظاهرا','ع','عاجزانه','عادلانه','عاقبت','عاقلانه','عالمانه',
               'عالي','عبارتند','عجب','عجولانه','عرفاني','عزيز','عقب','عقبتر','علاوه','علنا',
               'عليرغم','عليه','عمدا','عمدتا','عمده','عمدي','عملا','عملي','عملگرايانه','عموم',
               'عموما','عميقا','عن','عنقريب','عينا','غ','غالبا','غزالان','غير','غيراز','غيرازان',
               'غيرازاين','غيرتصادفي','غيرطبيعي','غيرعمدي','غيرمستقيم','غيريكسان','ف','فاقد',
               'فبها','فر','فراتر','فراتراز','فراوان','فردا','فعالانه','فعلا','فقط','فكورانه',
               'فلان','فلذا','فناورانه','فهرستوار','فورا','فوري','فوق','ق','قاالند','قابل',
               'قاطبه','قاطعانه','قاعدتا','قانونا','قبل','قبلا','قبلند','قد','قدر','قدرمسلم',
               'قدري','قرار','قراردادن','قريب','قضاياست','قطعا','قيلا','ك','كارافرينانه',
               'كاربرمدارانه','كارند','كاش','كاشكي','كاملا','كاملتر','كان','كاين','كجا','كجاست',
               'كدام','كدامند','كداميك','كرات','كرد','كردن','كرده','كز','كزين','كس','كساني','كسي',
               'كشيدن','كل','كلا','كلي','كليشه','كم','كمااينكه','كمابيش','كماكان','كمتر','كمتره','كمي',
               'كنار','كنارش','كنان','كنايه','كند','كنم','كنند','كننده','كه','كودكانه','كوركورانه'
               ,'كي','كيست','ل','لا','لااقل','لاجرم','لب','لذا','لزوما','لطفا','ليكن','م','ما',
               'مات','مادام','مادامي','ماداميكه','ماست','ماشينوار','ماقبل','مالا','مالامال','مامان',
               'مانند','ماهرانه','ماهيتا','مايي','مبادا','متاسفانه','متعاقبا','متفاوتند','متفكرانه',
               'متقابلا','متوالي','متوسفانه','مثابه','مثل','مثلا','مجبورند','مجددا','مجرمانه','مجموع',
               'مجموعا','محتاجند','محتاط','محتاطانه','محكم','مخالفند','مختصر','مختصرا','مخصوصا',
               'مدام','مداوم','مدبر','مدبرانه','مدتهاست','مدتي','مرا','مراتب','مرتب','مرتبا',
               'مردانه','مستحضريد','مستعد','مستقلا','مستقيم','مستقيما','مستمر','مستمرا',
               'مستند','مسلم','مسلما','مسيولانه','مشت','مشتركا','مشخص','مشغول','مشغولند',
               'مشكل','مشكلتر','مطلق','مطلقا','مطمانا','مطمانم','مطمنا','مع','معتقدم','معتقدند',
               'معتقديم','معدود','معذوريم','معلق','معلومه','معمولا','معمولي','مغرضانه','مغلوب',
               'مفيدند','مقدار','مقصر','مقصري','مقلوب','مكرر','مكررا','ملزم','مميزيهاست','من',
               'منتهي','منحصر','منحصرا','منحصربفرد','منصفانه','منطقا','منطقي','مني','مواجهند',
               'موجب','موجودند','موخر','مورد','موقعيكه','مي','ميان','ميزان','مگر','مگرانكه',
               'مگراينكه','ن','نااميد','نااگاهانه','ناتوان','ناخواسته','ناخوانده','ناديده'
               ,'ناراضي','ناسازگارانه','ناشناخته','ناكام','ناهشيار','ناپذير','ناچار'
               ,'ناگزير','ناگهان','نبايد','نبش','نتيجتا','نخست','نخودي','ندارد','ندرت',
               'ندرتا','نرم','نرمي','نزد','نزديك','نزديكتر','نسبت','نظرا','نظربه','نظير',
               'نفرند','نفهمي','نقادانه','نمي','نه','نهان','نهايت','نهايتا','نواورانه',
               'نوع','نوعا','نوميد','نيازمندانه','نيازمندند','نيز','نيست','نيك','نيمي',
               'ه','ها','هاست','هان','هايي','هدف','هر','هرازچندگاهي','هرانچه','هرجا'
               ,'هرزچندگاهي','هرساله','هرقدر','هركدام','هركس','هركسي','هركه','هروقت',
               'هرچقدر','هرچند','هرچه','هرگاه','هرگز','هرگونه','هزارها','هست','هستند'
               ,'هشيارانه','هق','هم','همان','همانا','همانطور','همانطوركه','همانطوري'
               ,'همانطوريكه','همانقدر','همانند','همانها','هماني','هماهنگتر','همخوان'
               ,'همدلانه','همديگر','همزمان','همسو','همسوبا','همكارانه','همنوا','همه'
               ,'همواره','همي','هميشه','هميشگي','همين','همينطور','همينطوركه','همينطوري'
               ,'همينطوريكه','همينكه','همچنان','همچنانكه','همچنين','همچون','همچين','همگام',
               'همگان','همگي','هنوز','هنگاميكه','هوشمندانه','هوشيارانه','هوي','هي','هيچ','هيچكدام',
               'هيچكس','هيچي','هيچيك','هيچگاه','هيچگونه','وابسته','واضح','واضحتر','واقع','واقعا','واقعي',
               'واقفند','واي','وجه','وجود','وجوديكه','وحشت','ور','ورا','وراي','وزو','وضوح','وقتي','وقتيكه'
               ,'ولي','وليكن','وهمين','وي','ويا','ويژه','وگر','وگرنه','يا','يااز','ياانكه','يااينكه','يابد','يارب'
               ,'يافتن','يعني','يقينا','يك','يكايك','يكبار','يكباره','يكجا','يكجانبه','يكجور','يكجوري','يكدم'
               ,'يكديگر','يكريز','يكزمان','يكسال','يكسره','يكسري','يكطرفه','يكنواخت','يكي','يكپارچه','يه'
               ,'يواش','پ','پارسال','پارسايانه','پاره','پايين','پدرانه','پدرپي','پديده','پذير','پذيرند'
               ,'پراكنده','پرتحرك','پرخاشگرانه','پرسان','پرشتاب','پرشور','پروردگارا','پريروز','پس','پشت'
               ,'پشتوانه','پشيموني','پنهان','پهن','پي','پيامبرانه','پيداست','پيدرپي','پيرامون','پيش'
               ,'پيشاپيش','پيشتر','پيوسته','پيگير','چ','چارده','چاله','چاپلوسانه','چت','چته','چرا'
               ,'چراكه','چطور','چقدر','چكار','چنان','چنانكه','چنانچه','چند','چندان','چنداني'
               ,'چندروزه','چندماهه','چندمين','چنده','چندين','چنين','چه','چهارهزار','چو','چون'
               ,'چي','چيز','چيزهاست','چيزيست','چيست','چيه','چگونه','ژ','گ','گاه','گاهي'
               ,'گذاران','گذاري','گذاشتن','گر','گرديد','گرفتارند','گرفتن','گرمي','گرنه'
               ,'گرچه','گفت','گمان','گهگاه','گونه','گويا','گويان','گويي','ابلهانه ها',
           
               'این','در','که','می','های','است','کرد' ,'برای'
           ,'شود'
           ,'آن'
           ,'وی'
           ,'نیز'
           ,'یک'
          
          }

def removeStopwords(text):
    regex = r"(?<!\d)[.,;:«»()،-](?!\d)"
    regex_number=r"\d+"
    regex_english=r"[a-zA-Z]+"
    subst=""
    #text=re.sub(regex, subst, text, 0)
    text=re.sub(regex_number,"",text,0)
    #text=re.sub(regex_english,"",text,0)
    words = []
    tokens = [word for word in text.split(' ') if word]
    for w in tokens:
        
        if w not in stopwords:
            
            words.append(w)
    return ' '.join(filter(lambda x: x.isalpha(), words))

def Load_Corpus(Normalize=True,RemoveStopWord=True,RemoveEnglishWord=True):
    new_data=pd.read_csv("Corpus_news.csv")
    normalizer = Normalizer()
    if Normalize==True:
        new_data['Content']=[normalizer.normalize(item.decode('utf-8')) for item in new_data['Content']]
    if RemoveStopWord==True:
        new_data['Content']=[removeStopwords(item) for item in new_data['Content']]
    if RemoveEnglishWord==True:
        new_data['Content']=[re.sub("[a-zA-Z]+","",item) for item in new_data['Content']]
    return new_data


def plot_confusion_matrix(Y_test, Y_pred):
    conf_mat = confusion_matrix(y_true=Y_test, y_pred=Y_pred)
    fig, ax = plt.subplots(figsize=(10,10))
    sns.heatmap(conf_mat, annot=True, fmt='d',
            xticklabels=Cat_count.index, yticklabels=Cat_count.index)
    plt.ylabel('Actual')
    plt.xlabel('Predicted')
    plt.show()

# %%
precisions_micro = []
precisions_macro = []
recalls_micro = []
recalls_macro = []
f1s_micro = []
f1s_macro = []

# %%
news=news1[news1.Cat_Idx==1 ]
Cat=news['Cat'].value_counts()

X_train, X_test, Y_train, Y_test = train_test_split(news['Content'], news['Cat_Idx'], test_size=0.0)
count_vectorizer = CountVectorizer(ngram_range=(1, 1),min_df=2)
X=count_vectorizer.fit_transform(X_train)

df3=pd.DataFrame()
df3['Word']=count_vectorizer.get_feature_names()
df3['Count']=X.toarray().sum(axis=0)
df3.to_csv(Cat.index[0]+'.csv',encoding="utf-8")

#load to dataframe 
d_Law=pd.read_csv("d1/Law.csv")
d_Economic=pd.read_csv("d1/Economic.csv")
d_Educational=pd.read_csv("d1/Educational.csv")
d_Religion=pd.read_csv("d1/Religion.csv")
d_Political=pd.read_csv("d1/Political.csv")
d_Social=pd.read_csv("d1/Social.csv")
d_Scientific=pd.read_csv("d1/Scientific.csv")
d_Health=pd.read_csv("d1/Health.csv")
d_Cultural=pd.read_csv("d1/Cultural.csv")
d_History=pd.read_csv("d1/History.csv")
d_Sport=pd.read_csv("d1/Sport.csv")

#cretae ontology step 1 All Word - Category words
Cat=news1['Cat'].value_counts()

ontology_all={}
for item,key in  enumerate(Cat.index):
    print item,key
    news=news1[news1.Cat_Idx!=item+1 ]
    X_train, X_test, Y_train, Y_test = train_test_split(news['Content'], news['Cat_Idx'], test_size=0.0)
    count_vectorizer = CountVectorizer(ngram_range=(1, 1),min_df=2)
    X=count_vectorizer.fit_transform(X_train)

    df3=pd.DataFrame()
    df3['Word']=count_vectorizer.get_feature_names()
    ontology_all[key]=set(count_vectorizer.get_feature_names())
    print(len(ontology_all[key]))
    


#Create ontology step 2 category words
Cat=news1['Cat'].value_counts()

ontology_dic={}
for item,key in  enumerate(Cat.index):
    print item,key
    news=news1[news1.Cat_Idx==item+1 ]
    Cat=news['Cat'].value_counts()

    X_train, X_test, Y_train, Y_test = train_test_split(news['Content'], news['Cat_Idx'], test_size=0.0)
    count_vectorizer = CountVectorizer(ngram_range=(1, 1),min_df=2)
    X=count_vectorizer.fit_transform(X_train)

    df3=pd.DataFrame()
    df3['Word']=count_vectorizer.get_feature_names()
    ontology_dic[key]=set(count_vectorizer.get_feature_names())
    print(len(ontology_dic[key]))

# create ontalogy step 3 clear words for each category 
Cat=news1['Cat'].value_counts()
ontology={}
for item,key in  enumerate(Cat.index):
    ontology[key]=ontology_dic[key] - ontology_all[key]
    print(key,len(ontology[key]))
    
#show for one category 
df0=pd.DataFrame()
for item in ontology['History']:
    print item
    df0 = df0.append({'Word': item}, ignore_index=True)
print(df0.shape[0])

# %%
start = datetime.datetime.now()
news_data=Load_Corpus(Normalize=True,RemoveStopWord=True,RemoveEnglishWord=True)
#news_data2=Load_Corpus(Normalize=True,RemoveStopWord=False,RemoveEnglishWord=True)
end = datetime.datetime.now()
print ("Time:{}".format(end-start))
# Out:
# Time:0:00:20.286633

# %%
#remove Historey data 
news_data=news_data[news_data.Cat_Idx !=10 ]
#news_data2=news_data[news_data.Cat_Idx !=10 ]
#news_data=news2

# %%
Cat_count=news_data['Cat'].value_counts()
Cat_count
plt.figure(figsize=(11,5))
sns.barplot(Cat_count.index, Cat_count.values, alpha=0.8)
plt.title(u'News Category')
plt.ylabel(u'Number of Occurrences', fontsize=12)
plt.xlabel(u'Category', fontsize=12)
plt.show()

# %%
X_train, X_test, Y_train, Y_test = train_test_split(news_data['Content'], news_data['Cat_Idx'], test_size=0.25,random_state=1)

# %%
count_vectorizer = CountVectorizer()
multinomialNB = MultinomialNB()



# Define pipeline
mn_cv_nb_pipeline = Pipeline([('vectorizer', count_vectorizer),
                             ('multinomial_nb', multinomialNB)])

# Grid search parameters
mn_cv_nb_param_grid = [
    { 
        'vectorizer__min_df': [ 1 ],
        'vectorizer__ngram_range': [ (1,1),(1,2),(1,3) ],
        'multinomial_nb__alpha': [  0.5 ]
    }
]

# Perform grid search
mn_cv_nb_gs = GridSearchCV(estimator=mn_cv_nb_pipeline, param_grid=mn_cv_nb_param_grid, 
                           scoring='accuracy', cv=25, n_jobs=multiprocessing.cpu_count())

mn_cv_nb_gs.fit(X_train, Y_train)

# Create an instance of the best estimator
mn_cv_nb_best = mn_cv_nb_gs.best_estimator_
mn_cv_nb_best.fit(X_train, Y_train)

print('Best model: %s' % str(mn_cv_nb_gs.best_params_))
print('Best score: %f' % mn_cv_nb_gs.best_score_)
print('Best test accuracy: %f' % mn_cv_nb_best.score(X_test, Y_test))
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-18-f995e9d66381> in <module>()
#      37                            scoring='accuracy', cv=25, n_jobs=multiprocessing.cpu_count())
#      38
# ---> 39 mn_cv_nb_gs.fit(X_train, Y_train)
#      40
#      41 # Create an instance of the best estimator
#
# /anaconda2/lib/python2.7/site-packages/sklearn/model_selection/_search.pyc in fit(self, X, y, groups, **fit_params)
#     638                                   error_score=self.error_score)
#     639           for parameters, (train, test) in product(candidate_params,
# --> 640                                                    cv.split(X, y, groups)))
#     641
#     642         # if one choose to see train score, "out" will contain train score info
#
# /anaconda2/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.pyc in __call__(self, iterable)
#     787                 # consumption.
#     788                 self._iterating = False
# --> 789             self.retrieve()
#     790             # Make sure that we get a last message telling us we are done
#     791             elapsed_time = time.time() - self._start_time
#
# /anaconda2/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.pyc in retrieve(self)
#     727                     # stack in addition to the distant stack
#     728                     this_report = format_outer_frames(context=10,
# --> 729                                                       stack_start=1)
#     730                     report = """Multiprocessing exception:
#     731 %s
#
# /anaconda2/lib/python2.7/site-packages/sklearn/externals/joblib/format_stack.pyc in format_outer_frames(context, stack_start, stack_end, ignore_ipython)
#     399         buf[LINES_POS] = lines
#     400         output.append(tuple(buf))
# --> 401     return '\n'.join(format_records(output[stack_end:stack_start:-1]))
#
# UnicodeDecodeError: 'ascii' codec can't decode byte 0xd8 in position 275: ordinal not in range(128)

# %%
mn_cv_nb_Y_pred = mn_cv_nb_best.predict(X_test)

# Compute precision, recall and F1 scores with micro and macro averaging
mn_cv_nb_precision_micro = precision_score(y_true=Y_test, y_pred=mn_cv_nb_Y_pred, average='micro')
mn_cv_nb_precision_macro = precision_score(y_true=Y_test, y_pred=mn_cv_nb_Y_pred, average='macro')
mn_cv_nb_recall_micro = recall_score(y_true=Y_test, y_pred=mn_cv_nb_Y_pred, average='micro')
mn_cv_nb_recall_macro = recall_score(y_true=Y_test, y_pred=mn_cv_nb_Y_pred, average='macro')
mn_cv_nb_f1_micro = f1_score(y_true=Y_test, y_pred=mn_cv_nb_Y_pred, average='micro')
mn_cv_nb_f1_macro = f1_score(y_true=Y_test, y_pred=mn_cv_nb_Y_pred, average='macro')

precisions_micro.append(mn_cv_nb_precision_micro)
precisions_macro.append(mn_cv_nb_precision_macro)
recalls_micro.append(mn_cv_nb_recall_micro)
recalls_macro.append(mn_cv_nb_recall_macro)
f1s_micro.append(mn_cv_nb_f1_micro)
f1s_macro.append(mn_cv_nb_f1_macro)

print('Precision score: %f (micro) / %f (macro)' % (mn_cv_nb_precision_micro, mn_cv_nb_precision_macro))
print('Recall score: %f (micro) / %f (macro)' % (mn_cv_nb_recall_micro, mn_cv_nb_recall_macro))
print('F1 score: %f (micro) / %f (macro)' % (mn_cv_nb_f1_micro, mn_cv_nb_f1_macro))

# Compute confusion matrix
#confusion_matrix(Y_test, mn_cv_nb_Y_pred)
plot_confusion_matrix(Y_test, mn_cv_nb_Y_pred)
# Out:
# Precision score: 0.827600 (micro) / 0.833999 (macro)
# Recall score: 0.827600 (micro) / 0.829267 (macro)
# F1 score: 0.827600 (micro) / 0.821822 (macro)

# %%
confusion_matrix(Y_test, mn_cv_nb_Y_pred)
# Out:
# array([[126,   4,  10,  20,   7,  32,   7,  22,  23,   3],
#        [  3, 158,   6,   8,   2,  11,  29,   8,  33,   1],
#        [  5,   5, 228,   5,   3,   3,   2,   4,   5,   1],
#        [  2,   0,   1, 218,   1,   2,   0,   3,   4,   0],
#        [  4,   0,   4,   1, 242,   1,   0,   2,   0,   1],
#        [  7,   6,   4,   6,   6, 199,   3,   8,   5,   0],
#        [  0,   2,   0,   1,   0,   1, 237,   1,   5,   1],
#        [  0,   2,   2,  25,   2,   8,   6, 192,  12,   0],
#        [  0,   3,   1,   0,   0,   1,   0,   2, 249,   1],
#        [  4,   1,   1,   3,   0,   1,   2,   9,   1, 220]])

# %%
tfidf_vectorizer = TfidfVectorizer()
multinomialNB = MultinomialNB()

# Define pipeline
mn_tfidfv_nb_pipeline = Pipeline([('vectorizer', tfidf_vectorizer),
                             ('multinomial_nb', multinomialNB)])

# Grid search parameters
#        'vectorizer__min_df': [ 1, 2, 3, 4, 5 ],
#        'vectorizer__ngram_range': [ (1, 1), (1, 2), (1, 3) ],
#        'vectorizer__norm': [ None, 'l1', 'l2' ],
#        'vectorizer__smooth_idf': [True, False],
#        'multinomial_nb__alpha': [ 0.0, 0.25, 0.5, 0.75, 1.0 ]
mn_tfidfv_nb_param_grid = [
    { 
        'vectorizer__min_df': [ 1],
        'vectorizer__ngram_range': [  (1, 3) ],
        'vectorizer__norm': [ None ],
        
        'multinomial_nb__alpha': [0.5 ]
    }
]

# Perform grid search
mn_tfidfv_nb_gs = GridSearchCV(estimator=mn_tfidfv_nb_pipeline, param_grid=mn_tfidfv_nb_param_grid, 
                           scoring='accuracy', cv=25, n_jobs=multiprocessing.cpu_count())

mn_tfidfv_nb_gs.fit(X_train, Y_train)

# Create an instance of the best estimator
mn_tfidfv_nb_best = mn_tfidfv_nb_gs.best_estimator_
mn_tfidfv_nb_best.fit(X_train, Y_train)

print('Best model: %s' % str(mn_tfidfv_nb_gs.best_params_))
print('Best score: %f' % mn_tfidfv_nb_gs.best_score_)
print('Best test accuracy: %f' % mn_tfidfv_nb_best.score(X_test, Y_test))
# Out:
# Best model: {u'vectorizer__min_df': 1, u'multinomial_nb__alpha': 0.5, u'vectorizer__ngram_range': (1, 3), u'vectorizer__norm': None}
# Best score: 0.827067
# Best test accuracy: 0.834000

# %%
mn_cv_nb_Y_pred = mn_tfidfv_nb_gs.predict(X_test)

# Compute precision, recall and F1 scores with micro and macro averaging
mn_cv_nb_precision_micro = precision_score(y_true=Y_test, y_pred=mn_cv_nb_Y_pred, average='micro')
mn_cv_nb_precision_macro = precision_score(y_true=Y_test, y_pred=mn_cv_nb_Y_pred, average='macro')
mn_cv_nb_recall_micro = recall_score(y_true=Y_test, y_pred=mn_cv_nb_Y_pred, average='micro')
mn_cv_nb_recall_macro = recall_score(y_true=Y_test, y_pred=mn_cv_nb_Y_pred, average='macro')
mn_cv_nb_f1_micro = f1_score(y_true=Y_test, y_pred=mn_cv_nb_Y_pred, average='micro')
mn_cv_nb_f1_macro = f1_score(y_true=Y_test, y_pred=mn_cv_nb_Y_pred, average='macro')

precisions_micro.append(mn_cv_nb_precision_micro)
precisions_macro.append(mn_cv_nb_precision_macro)
recalls_micro.append(mn_cv_nb_recall_micro)
recalls_macro.append(mn_cv_nb_recall_macro)
f1s_micro.append(mn_cv_nb_f1_micro)
f1s_macro.append(mn_cv_nb_f1_macro)

print('Precision score: %f (micro) / %f (macro)' % (mn_cv_nb_precision_micro, mn_cv_nb_precision_macro))
print('Recall score: %f (micro) / %f (macro)' % (mn_cv_nb_recall_micro, mn_cv_nb_recall_macro))
print('F1 score: %f (micro) / %f (macro)' % (mn_cv_nb_f1_micro, mn_cv_nb_f1_macro))

# Compute confusion matrix
#confusion_matrix(Y_test, mn_cv_nb_Y_pred)
plot_confusion_matrix(Y_test, mn_cv_nb_Y_pred)
# Out:
# Precision score: 0.834000 (micro) / 0.836332 (macro)
# Recall score: 0.834000 (micro) / 0.835240 (macro)
# F1 score: 0.834000 (micro) / 0.829629 (macro)

# %% [markdown]
# ## Gradiant

# %%
#count_vectorizer = CountVectorizer(ngram_range=(1, 1),min_df=2)
#X=count_vectorizer.fit_transform(X_train)
#Xtest=count_vectorizer.transform(X_test)
gnb = GaussianNB()
#gnb.fit(X,Y_train)


v = TfidfVectorizer(ngram_range=(1,2))  
x = v.fit_transform(X_train.astype('U')).toarray()  

gnb.fit(x,Y_train)
xtest = v.transform(X_test.astype('U')).toarray()  
y_pred=gnb.predict(xtest)
yscore=gnb.score(xtest,Y_test)
print(yscore)

# %%
mn_cv_nb_Y_pred = gnb.predict(xtest)

# Compute precision, recall and F1 scores with micro and macro averaging
mn_cv_nb_precision_micro = precision_score(y_true=Y_test, y_pred=mn_cv_nb_Y_pred, average='micro')
mn_cv_nb_precision_macro = precision_score(y_true=Y_test, y_pred=mn_cv_nb_Y_pred, average='macro')
mn_cv_nb_recall_micro = recall_score(y_true=Y_test, y_pred=mn_cv_nb_Y_pred, average='micro')
mn_cv_nb_recall_macro = recall_score(y_true=Y_test, y_pred=mn_cv_nb_Y_pred, average='macro')
mn_cv_nb_f1_micro = f1_score(y_true=Y_test, y_pred=mn_cv_nb_Y_pred, average='micro')
mn_cv_nb_f1_macro = f1_score(y_true=Y_test, y_pred=mn_cv_nb_Y_pred, average='macro')

precisions_micro.append(mn_cv_nb_precision_micro)
precisions_macro.append(mn_cv_nb_precision_macro)
recalls_micro.append(mn_cv_nb_recall_micro)
recalls_macro.append(mn_cv_nb_recall_macro)
f1s_micro.append(mn_cv_nb_f1_micro)
f1s_macro.append(mn_cv_nb_f1_macro)

print('Precision score: %f (micro) / %f (macro)' % (mn_cv_nb_precision_micro, mn_cv_nb_precision_macro))
print('Recall score: %f (micro) / %f (macro)' % (mn_cv_nb_recall_micro, mn_cv_nb_recall_macro))
print('F1 score: %f (micro) / %f (macro)' % (mn_cv_nb_f1_micro, mn_cv_nb_f1_macro))

# Compute confusion matrix
plot_confusion_matrix(Y_test, mn_cv_nb_Y_pred)
# Out:
# Precision score: 0.604800 (micro) / 0.613441 (macro)
# Recall score: 0.604800 (micro) / 0.607058 (macro)
# F1 score: 0.604800 (micro) / 0.606088 (macro)

# %%
tfidf_vectorizer = TfidfVectorizer()
multinomialNB = MultinomialNB()

# Define pipeline
mn_tfidfv_nb_pipeline = Pipeline([('vectorizer', tfidf_vectorizer),
                             ('multinomial_nb', multinomialNB)])

# Grid search parameters
mn_tfidfv_nb_param_grid = [
    { 
        'vectorizer__min_df': [ 1,2,3 ],
        'vectorizer__ngram_range': [  (1, 2) ],
        'vectorizer__norm': [ None, 'l1', 'l2' ],
        'vectorizer__smooth_idf': [True, False],
        'multinomial_nb__alpha': [  0.5 ]
    }
]

# Perform grid search
mn_tfidfv_nb_gs = GridSearchCV(estimator=mn_tfidfv_nb_pipeline, param_grid=mn_tfidfv_nb_param_grid, 
                           scoring='accuracy', cv=25, n_jobs=multiprocessing.cpu_count())

mn_tfidfv_nb_gs.fit(X_train, Y_train)

# Create an instance of the best estimator
mn_tfidfv_nb_best = mn_tfidfv_nb_gs.best_estimator_
mn_tfidfv_nb_best.fit(X_train, Y_train)

print('Best model: %s' % str(mn_tfidfv_nb_gs.best_params_))
print('Best score: %f' % mn_tfidfv_nb_gs.best_score_)
print('Best test accuracy: %f' % mn_tfidfv_nb_best.score(X_test, Y_test))
# Out:
# Best model: {u'vectorizer__min_df': 1, u'multinomial_nb__alpha': 0.5, u'vectorizer__ngram_range': (1, 2), u'vectorizer__norm': None, u'vectorizer__smooth_idf': True}
# Best score: 0.820133
# Best test accuracy: 0.815200

# %%
mn_tfidfv_nb_Y_pred = mn_tfidfv_nb_best.predict(X_test)

# Compute precision, recall and F1 scores with micro and macro averaging
mn_tfidfv_nb_precision_micro = precision_score(y_true=Y_test, y_pred=mn_tfidfv_nb_Y_pred, average='micro')
mn_tfidfv_nb_precision_macro = precision_score(y_true=Y_test, y_pred=mn_tfidfv_nb_Y_pred, average='macro')
mn_tfidfv_nb_recall_micro = recall_score(y_true=Y_test, y_pred=mn_tfidfv_nb_Y_pred, average='micro')
mn_tfidfv_nb_recall_macro = recall_score(y_true=Y_test, y_pred=mn_tfidfv_nb_Y_pred, average='macro')
mn_tfidfv_nb_f1_micro = f1_score(y_true=Y_test, y_pred=mn_tfidfv_nb_Y_pred, average='micro')
mn_tfidfv_nb_f1_macro = f1_score(y_true=Y_test, y_pred=mn_tfidfv_nb_Y_pred, average='macro')

precisions_micro.append(mn_tfidfv_nb_precision_micro)
precisions_macro.append(mn_tfidfv_nb_precision_macro)
recalls_micro.append(mn_tfidfv_nb_recall_micro)
recalls_macro.append(mn_tfidfv_nb_recall_macro)
f1s_micro.append(mn_tfidfv_nb_f1_micro)
f1s_macro.append(mn_tfidfv_nb_f1_macro)

print('Precision score: %f (micro) / %f (macro)' % (mn_tfidfv_nb_precision_micro, mn_tfidfv_nb_precision_macro))
print('Recall score: %f (micro) / %f (macro)' % (mn_tfidfv_nb_recall_micro, mn_tfidfv_nb_recall_macro))
print('F1 score: %f (micro) / %f (macro)' % (mn_tfidfv_nb_f1_micro, mn_tfidfv_nb_f1_macro))

# Compute confusion matrix
plot_confusion_matrix(Y_test, mn_tfidfv_nb_Y_pred)
# Out:
# Precision score: 0.815200 (micro) / 0.814057 (macro)
# Recall score: 0.815200 (micro) / 0.817321 (macro)
# F1 score: 0.815200 (micro) / 0.811783 (macro)

# %%
start = datetime.datetime.now()

count_vectorizer = CountVectorizer(ngram_range=(1, 1),min_df=2)
X=count_vectorizer.fit_transform(X_train)
Xtest=count_vectorizer.transform(X_test)
end = datetime.datetime.now()
print ("Time:{}".format(end-start))
# Out:
# Time:0:00:06.348363

# %%
algo = MultinomialNB(alpha=0.5)
algo.fit(X,Y_train)
y_pred=algo.predict()
yscore=algo.score(Xtest,Y_test)
print(yscore)

plot_confusion_matrix(Y_test,y_pred)
# Out:
# 0.7956

# %%
rf = RandomForestClassifier(n_jobs=2, random_state=0)
rf.fit(X,Y_train)
y_pred = rf.predict(Xtest)
yscore=metrics.accuracy_score(Y_test,y_pred)
print(yscore)
plot_confusion_matrix(Y_test,y_pred)
# Out:
# 0.7144

# %%
##Test for ontology 
y_pred=algo.predict(Xtest)
Y_test1=Y_test.reset_index()
X_test1=X_test.reset_index()
for index,val in enumerate( y_pred):
    if val !=Y_test1.loc[index].Cat_Idx:
        print ("Item:{} Pred:{} Answer:{}".format(index,val,Y_test1.loc[index].Cat_Idx))
        test_onto(index)
#print (y_pred)
# Out:
# Item:7 Pred:4 Answer:6
# True:Economic   False:Law
# in Economic :51 and in Law :54
#
# Item:19 Pred:2 Answer:9
# True:Educational   False:Scientific
# in Educational :56 and in Scientific :50
#
# Item:23 Pred:6 Answer:8
# True:Political   False:Economic
# in Political :79 and in Economic :84
#
# Item:24 Pred:5 Answer:6
# True:Economic   False:Religion
# in Economic :65 and in Religion :62
#
# Item:27 Pred:2 Answer:1
# True:Social   False:Scientific
# in Social :36 and in Scientific :35
#
# Item:30 Pred:9 Answer:1
# True:Social   False:Educational
# in Social :4 and in Educational :4
#
# Item:37 Pred:6 Answer:8
# True:Political   False:Economic
# in Political :105 and in Economic :106
#
# Item:40 Pred:2 Answer:7
# True:Health   False:Scientific
# in Health :84 and in Scientific :87
#
# Item:41 Pred:4 Answer:8
# True:Political   False:Law
# in Political :191 and in Law :192
#
# Item:57 Pred:9 Answer:1
# True:Social   False:Educational
# in Social :67 and in Educational :69
#
# Item:61 Pred:5 Answer:3
# True:Cultural   False:Religion
# in Cultural :28 and in Religion :30
#
# Item:62 Pred:9 Answer:1
# True:Social   False:Educational
# in Social :36 and in Educational :40
#
# Item:67 Pred:9 Answer:2
# True:Scientific   False:Educational
# in Scientific :23 and in Educational :22
#
# Item:68 Pred:9 Answer:2
# True:Scientific   False:Educational
# in Scientific :52 and in Educational :52
#
# Item:70 Pred:5 Answer:6
# True:Economic   False:Religion
# in Economic :13 and in Religion :12
#
# Item:71 Pred:2 Answer:7
# True:Health   False:Scientific
# in Health :60 and in Scientific :69
#
# Item:76 Pred:2 Answer:8
# True:Political   False:Scientific
# in Political :20 and in Scientific :22
#
# Item:82 Pred:4 Answer:8
# True:Political   False:Law
# in Political :122 and in Law :123
#
# Item:104 Pred:9 Answer:1
# True:Social   False:Educational
# in Social :35 and in Educational :37
#
# Item:110 Pred:5 Answer:1
# True:Social   False:Religion
# in Social :42 and in Religion :44
#
# Item:111 Pred:8 Answer:3
# True:Cultural   False:Political
# in Cultural :192 and in Political :197
#
# Item:112 Pred:4 Answer:1
# True:Social   False:Law
# in Social :92 and in Law :111
#
# Item:114 Pred:8 Answer:4
# True:Law   False:Political
# in Law :44 and in Political :44
#
# Item:122 Pred:5 Answer:3
# True:Cultural   False:Religion
# in Cultural :30 and in Religion :29
#
# Item:125 Pred:8 Answer:4
# True:Law   False:Political
# in Law :106 and in Political :112
#
# Item:129 Pred:6 Answer:1
# True:Social   False:Economic
# in Social :175 and in Economic :170
#
# Item:131 Pred:4 Answer:8
# True:Political   False:Law
# in Political :376 and in Law :381
#
# Item:134 Pred:7 Answer:5
# True:Religion   False:Health
# in Religion :70 and in Health :73
#
# Item:138 Pred:4 Answer:8
# True:Political   False:Law
# in Political :23 and in Law :26
#
# Item:143 Pred:9 Answer:1
# True:Social   False:Educational
# in Social :43 and in Educational :47
#
# Item:146 Pred:6 Answer:1
# True:Social   False:Economic
# in Social :63 and in Economic :62
#
# Item:147 Pred:6 Answer:2
# True:Scientific   False:Economic
# in Scientific :85 and in Economic :89
#
# Item:151 Pred:3 Answer:7
# True:Health   False:Cultural
# in Health :80 and in Cultural :79
#
# Item:156 Pred:6 Answer:2
# True:Scientific   False:Economic
# in Scientific :12 and in Economic :12
#
# Item:157 Pred:6 Answer:2
# True:Scientific   False:Economic
# in Scientific :58 and in Economic :62
#
# Item:160 Pred:6 Answer:2
# True:Scientific   False:Economic
# in Scientific :88 and in Economic :101
#
# Item:165 Pred:3 Answer:1
# True:Social   False:Cultural
# in Social :34 and in Cultural :42
#
# Item:166 Pred:1 Answer:2
# True:Scientific   False:Social
# in Scientific :177 and in Social :185
#
# Item:167 Pred:7 Answer:2
# True:Scientific   False:Health
# in Scientific :30 and in Health :25
#
# Item:168 Pred:6 Answer:1
# True:Social   False:Economic
# in Social :92 and in Economic :92
#
# Item:170 Pred:2 Answer:1
# True:Social   False:Scientific
# in Social :59 and in Scientific :58
#
# Item:171 Pred:2 Answer:8
# True:Political   False:Scientific
# in Political :36 and in Scientific :37
#
# Item:173 Pred:6 Answer:7
# True:Health   False:Economic
# in Health :193 and in Economic :196
#
# Item:184 Pred:5 Answer:1
# True:Social   False:Religion
# in Social :28 and in Religion :30
#
# Item:187 Pred:9 Answer:2
# True:Scientific   False:Educational
# in Scientific :154 and in Educational :162
#
# Item:192 Pred:7 Answer:2
# True:Scientific   False:Health
# in Scientific :90 and in Health :72
#
# Item:193 Pred:8 Answer:4
# True:Law   False:Political
# in Law :116 and in Political :121
#
# Item:195 Pred:9 Answer:1
# True:Social   False:Educational
# in Social :52 and in Educational :53
#
# Item:197 Pred:4 Answer:3
# True:Cultural   False:Law
# in Cultural :72 and in Law :73
#
# Item:201 Pred:8 Answer:6
# True:Economic   False:Political
# in Economic :98 and in Political :101
#
# Item:202 Pred:9 Answer:1
# True:Social   False:Educational
# in Social :70 and in Educational :71
#
# Item:217 Pred:8 Answer:5
# True:Religion   False:Political
# in Religion :83 and in Political :84
#
# Item:220 Pred:7 Answer:8
# True:Political   False:Health
# in Political :153 and in Health :166
#
# Item:223 Pred:6 Answer:1
# True:Social   False:Economic
# in Social :121 and in Economic :119
#
# Item:224 Pred:7 Answer:8
# True:Political   False:Health
# in Political :444 and in Health :506
#
# Item:228 Pred:5 Answer:4
# True:Law   False:Religion
# in Law :94 and in Religion :100
#
# Item:230 Pred:5 Answer:8
# True:Political   False:Religion
# in Political :15 and in Religion :13
#
# Item:245 Pred:8 Answer:6
# True:Economic   False:Political
# in Economic :52 and in Political :51
#
# Item:247 Pred:5 Answer:4
# True:Law   False:Religion
# in Law :26 and in Religion :29
#
# Item:248 Pred:9 Answer:7
# True:Health   False:Educational
# in Health :109 and in Educational :116
#
# Item:250 Pred:7 Answer:1
# True:Social   False:Health
# in Social :61 and in Health :67
#
# Item:254 Pred:9 Answer:4
# True:Law   False:Educational
# in Law :107 and in Educational :105
#
# Item:256 Pred:9 Answer:7
# True:Health   False:Educational
# in Health :10 and in Educational :9
#
# Item:260 Pred:1 Answer:4
# True:Law   False:Social
# in Law :63 and in Social :61
#
# Item:262 Pred:7 Answer:8
# True:Political   False:Health
# in Political :141 and in Health :154
#
# Item:263 Pred:9 Answer:4
# True:Law   False:Educational
# in Law :39 and in Educational :38
#
# Item:293 Pred:7 Answer:9
# True:Educational   False:Health
# in Educational :41 and in Health :38
#
# Item:294 Pred:6 Answer:1
# True:Social   False:Economic
# in Social :64 and in Economic :58
#
# Item:297 Pred:2 Answer:1
# True:Social   False:Scientific
# in Social :59 and in Scientific :63
#
# Item:300 Pred:6 Answer:7
# True:Health   False:Economic
# in Health :81 and in Economic :84
#
# Item:314 Pred:5 Answer:3
# True:Cultural   False:Religion
# in Cultural :17 and in Religion :18
#
# Item:315 Pred:8 Answer:4
# True:Law   False:Political
# in Law :99 and in Political :91
#
# Item:320 Pred:7 Answer:1
# True:Social   False:Health
# in Social :99 and in Health :108
#
# Item:323 Pred:9 Answer:2
# True:Scientific   False:Educational
# in Scientific :40 and in Educational :41
#
# Item:325 Pred:11 Answer:4
# True:Law   False:Sport
# in Law :29 and in Sport :31
#
# Item:333 Pred:2 Answer:1
# True:Social   False:Scientific
# in Social :19 and in Scientific :18
#
# Item:335 Pred:9 Answer:1
# True:Social   False:Educational
# in Social :60 and in Educational :69
#
# Item:346 Pred:9 Answer:1
# True:Social   False:Educational
# in Social :65 and in Educational :65
#
# Item:347 Pred:1 Answer:3
# True:Cultural   False:Social
# in Cultural :155 and in Social :164
#
# Item:350 Pred:5 Answer:4
# True:Law   False:Religion
# in Law :58 and in Religion :61
#
# Item:353 Pred:3 Answer:8
# True:Political   False:Cultural
# in Political :29 and in Cultural :28
#
# Item:357 Pred:9 Answer:8
# True:Political   False:Educational
# in Political :27 and in Educational :29
#
# Item:374 Pred:6 Answer:8
# True:Political   False:Economic
# in Political :36 and in Economic :35
#
# Item:380 Pred:8 Answer:1
# True:Social   False:Political
# in Social :58 and in Political :58
#
# Item:382 Pred:3 Answer:11
# True:Sport   False:Cultural
# in Sport :107 and in Cultural :104
#
# Item:383 Pred:2 Answer:7
# True:Health   False:Scientific
# in Health :123 and in Scientific :133
#
# Item:386 Pred:9 Answer:4
# True:Law   False:Educational
# in Law :76 and in Educational :77
#
# Item:387 Pred:6 Answer:1
# True:Social   False:Economic
# in Social :48 and in Economic :47
#
# Item:396 Pred:7 Answer:2
# True:Scientific   False:Health
# in Scientific :185 and in Health :172
#
# Item:409 Pred:2 Answer:1
# True:Social   False:Scientific
# in Social :55 and in Scientific :56
#
# Item:410 Pred:7 Answer:2
# True:Scientific   False:Health
# in Scientific :122 and in Health :116
#
# Item:417 Pred:4 Answer:1
# True:Social   False:Law
# in Social :26 and in Law :28
#
# Item:418 Pred:6 Answer:1
# True:Social   False:Economic
# in Social :57 and in Economic :55
#
# Item:424 Pred:9 Answer:7
# True:Health   False:Educational
# in Health :19 and in Educational :19
#
# Item:430 Pred:6 Answer:2
# True:Scientific   False:Economic
# in Scientific :71 and in Economic :77
#
# Item:434 Pred:5 Answer:4
# True:Law   False:Religion
# in Law :137 and in Religion :155
#
# Item:437 Pred:6 Answer:2
# True:Scientific   False:Economic
# in Scientific :12 and in Economic :13
#
# Item:438 Pred:4 Answer:8
# True:Political   False:Law
# in Political :14 and in Law :14
#
# Item:453 Pred:9 Answer:8
# True:Political   False:Educational
# in Political :45 and in Educational :49
#
# Item:468 Pred:4 Answer:8
# True:Political   False:Law
# in Political :77 and in Law :85
#
# Item:472 Pred:6 Answer:3
# True:Cultural   False:Economic
# in Cultural :22 and in Economic :24
#
# Item:481 Pred:1 Answer:2
# True:Scientific   False:Social
# in Scientific :149 and in Social :140
#
# Item:485 Pred:8 Answer:2
# True:Scientific   False:Political
# in Scientific :58 and in Political :58
#
# Item:488 Pred:7 Answer:2
# True:Scientific   False:Health
# in Scientific :174 and in Health :157
#
# Item:489 Pred:7 Answer:2
# True:Scientific   False:Health
# in Scientific :213 and in Health :165
#
# Item:491 Pred:9 Answer:2
# True:Scientific   False:Educational
# in Scientific :86 and in Educational :91
#
# Item:494 Pred:4 Answer:6
# True:Economic   False:Law
# in Economic :207 and in Law :219
#
# Item:503 Pred:8 Answer:2
# True:Scientific   False:Political
# in Scientific :43 and in Political :47
#
# Item:507 Pred:7 Answer:8
# True:Political   False:Health
# in Political :33 and in Health :39
#
# Item:509 Pred:3 Answer:8
# True:Political   False:Cultural
# in Political :25 and in Cultural :22
#
# Item:511 Pred:9 Answer:6
# True:Economic   False:Educational
# in Economic :66 and in Educational :67
#
# Item:512 Pred:1 Answer:6
# True:Economic   False:Social
# in Economic :118 and in Social :130
#
# Item:516 Pred:5 Answer:4
# True:Law   False:Religion
# in Law :26 and in Religion :27
#
# Item:517 Pred:9 Answer:3
# True:Cultural   False:Educational
# in Cultural :12 and in Educational :12
#
# Item:518 Pred:6 Answer:1
# True:Social   False:Economic
# in Social :157 and in Economic :152
#
# Item:520 Pred:1 Answer:7
# True:Health   False:Social
# in Health :35 and in Social :34
#
# Item:524 Pred:3 Answer:8
# True:Political   False:Cultural
# in Political :60 and in Cultural :63
#
# Item:527 Pred:7 Answer:2
# True:Scientific   False:Health
# in Scientific :126 and in Health :118
#
# Item:528 Pred:3 Answer:6
# True:Economic   False:Cultural
# in Economic :31 and in Cultural :31
#
# Item:536 Pred:4 Answer:1
# True:Social   False:Law
# in Social :88 and in Law :97
#
# Item:540 Pred:6 Answer:8
# True:Political   False:Economic
# in Political :109 and in Economic :115
#
# Item:541 Pred:2 Answer:6
# True:Economic   False:Scientific
# in Economic :66 and in Scientific :65
#
# Item:547 Pred:9 Answer:11
# True:Sport   False:Educational
# in Sport :4 and in Educational :4
#
# Item:548 Pred:2 Answer:6
# True:Economic   False:Scientific
# in Economic :107 and in Scientific :105
#
# Item:549 Pred:9 Answer:2
# True:Scientific   False:Educational
# in Scientific :78 and in Educational :79
#
# Item:552 Pred:11 Answer:4
# True:Law   False:Sport
# in Law :112 and in Sport :125
#
# Item:554 Pred:6 Answer:1
# True:Social   False:Economic
# in Social :173 and in Economic :161
#
# Item:571 Pred:8 Answer:1
# True:Social   False:Political
# in Social :146 and in Political :157
#
# Item:573 Pred:1 Answer:2
# True:Scientific   False:Social
# in Scientific :76 and in Social :73
# Item:577 Pred:4 Answer:1
# True:Social   False:Law
# in Social :211 and in Law :251
#
# Item:586 Pred:1 Answer:2
# True:Scientific   False:Social
# in Scientific :35 and in Social :37
#
# Item:587 Pred:4 Answer:8
# True:Political   False:Law
# in Political :44 and in Law :47
#
# Item:591 Pred:6 Answer:1
# True:Social   False:Economic
# in Social :47 and in Economic :43
#
# Item:596 Pred:7 Answer:11
# True:Sport   False:Health
# in Sport :177 and in Health :151
#
# Item:597 Pred:3 Answer:5
# True:Religion   False:Cultural
# in Religion :173 and in Cultural :142
#
# Item:599 Pred:6 Answer:2
# True:Scientific   False:Economic
# in Scientific :125 and in Economic :133
#
# Item:605 Pred:9 Answer:1
# True:Social   False:Educational
# in Social :8 and in Educational :8
#
# Item:608 Pred:1 Answer:5
# True:Religion   False:Social
# in Religion :46 and in Social :46
#
# Item:609 Pred:4 Answer:6
# True:Economic   False:Law
# in Economic :42 and in Law :46
#
# Item:613 Pred:9 Answer:4
# True:Law   False:Educational
# in Law :41 and in Educational :41
#
# Item:615 Pred:2 Answer:9
# True:Educational   False:Scientific
# in Educational :127 and in Scientific :126
#
# Item:627 Pred:1 Answer:7
# True:Health   False:Social
# in Health :66 and in Social :68
#
# Item:633 Pred:3 Answer:1
# True:Social   False:Cultural
# in Social :31 and in Cultural :29
#
# Item:634 Pred:11 Answer:2
# True:Scientific   False:Sport
# in Scientific :141 and in Sport :132
#
# Item:635 Pred:7 Answer:6
# True:Economic   False:Health
# in Economic :50 and in Health :50
#
# Item:638 Pred:8 Answer:11
# True:Sport   False:Political
# in Sport :71 and in Political :65
#
# Item:639 Pred:9 Answer:1
# True:Social   False:Educational
# in Social :40 and in Educational :43
#
# Item:656 Pred:8 Answer:1
# True:Social   False:Political
# in Social :147 and in Political :175
#
# Item:662 Pred:1 Answer:8
# True:Political   False:Social
# in Political :67 and in Social :72
#
# Item:666 Pred:2 Answer:1
# True:Social   False:Scientific
# in Social :98 and in Scientific :93
#
# Item:670 Pred:1 Answer:7
# True:Health   False:Social
# in Health :87 and in Social :81
#
# Item:673 Pred:6 Answer:2
# True:Scientific   False:Economic
# in Scientific :189 and in Economic :206
#
# Item:676 Pred:9 Answer:7
# True:Health   False:Educational
# in Health :38 and in Educational :40
#
# Item:679 Pred:2 Answer:1
# True:Social   False:Scientific
# in Social :144 and in Scientific :143
#
# Item:684 Pred:9 Answer:2
# True:Scientific   False:Educational
# in Scientific :114 and in Educational :119
#
# Item:697 Pred:9 Answer:3
# True:Cultural   False:Educational
# in Cultural :5 and in Educational :5
#
# Item:698 Pred:2 Answer:3
# True:Cultural   False:Scientific
# in Cultural :38 and in Scientific :41
#
# Item:709 Pred:5 Answer:8
# True:Political   False:Religion
# in Political :33 and in Religion :31
#
# Item:716 Pred:8 Answer:2
# True:Scientific   False:Political
# in Scientific :235 and in Political :240
#
# Item:718 Pred:3 Answer:1
# True:Social   False:Cultural
# in Social :80 and in Cultural :83
#
# Item:719 Pred:9 Answer:1
# True:Social   False:Educational
# in Social :4 and in Educational :4
#
# Item:722 Pred:9 Answer:7
# True:Health   False:Educational
# in Health :192 and in Educational :197
#
# Item:729 Pred:9 Answer:2
# True:Scientific   False:Educational
# in Scientific :104 and in Educational :98
#
# Item:730 Pred:9 Answer:1
# True:Social   False:Educational
# in Social :72 and in Educational :72
#
# Item:733 Pred:9 Answer:4
# True:Law   False:Educational
# in Law :11 and in Educational :12
#
# Item:735 Pred:4 Answer:8
# True:Political   False:Law
# in Political :72 and in Law :75
#
# Item:739 Pred:8 Answer:4
# True:Law   False:Political
# in Law :82 and in Political :93
#
# Item:746 Pred:9 Answer:3
# True:Cultural   False:Educational
# in Cultural :52 and in Educational :54
#
# Item:747 Pred:11 Answer:1
# True:Social   False:Sport
# in Social :29 and in Sport :31
#
# Item:749 Pred:8 Answer:1
# True:Social   False:Political
# in Social :38 and in Political :38
#
# Item:758 Pred:9 Answer:2
# True:Scientific   False:Educational
# in Scientific :33 and in Educational :35
#
# Item:764 Pred:9 Answer:3
# True:Cultural   False:Educational
# in Cultural :18 and in Educational :19
#
# Item:765 Pred:9 Answer:2
# True:Scientific   False:Educational
# in Scientific :53 and in Educational :58
#
# Item:769 Pred:1 Answer:3
# True:Cultural   False:Social
# in Cultural :63 and in Social :61
#
# Item:802 Pred:5 Answer:3
# True:Cultural   False:Religion
# in Cultural :62 and in Religion :60
#
# Item:807 Pred:8 Answer:6
# True:Economic   False:Political
# in Economic :56 and in Political :52
#
# Item:810 Pred:3 Answer:1
# True:Social   False:Cultural
# in Social :83 and in Cultural :83
#
# Item:818 Pred:8 Answer:3
# True:Cultural   False:Political
# in Cultural :631 and in Political :629
#
# Item:830 Pred:9 Answer:11
# True:Sport   False:Educational
# in Sport :4 and in Educational :4
#
# Item:838 Pred:1 Answer:11
# True:Sport   False:Social
# in Sport :40 and in Social :39
#
# Item:843 Pred:6 Answer:1
# True:Social   False:Economic
# in Social :79 and in Economic :77
#
# Item:847 Pred:2 Answer:3
# True:Cultural   False:Scientific
# in Cultural :175 and in Scientific :176
#
# Item:848 Pred:2 Answer:6
# True:Economic   False:Scientific
# in Economic :55 and in Scientific :54
#
# Item:852 Pred:3 Answer:1
# True:Social   False:Cultural
# in Social :89 and in Cultural :90
#
# Item:855 Pred:3 Answer:1
# True:Social   False:Cultural
# in Social :38 and in Cultural :35
#
# Item:860 Pred:9 Answer:1
# True:Social   False:Educational
# in Social :68 and in Educational :71
#
# Item:868 Pred:1 Answer:8
# True:Political   False:Social
# in Political :120 and in Social :123
#
# Item:878 Pred:6 Answer:1
# True:Social   False:Economic
# in Social :129 and in Economic :120
#
# Item:882 Pred:4 Answer:1
# True:Social   False:Law
# in Social :66 and in Law :72
#
# Item:883 Pred:6 Answer:1
# True:Social   False:Economic
# in Social :71 and in Economic :69
#
# Item:889 Pred:4 Answer:8
# True:Political   False:Law
# in Political :80 and in Law :85
#
# Item:892 Pred:3 Answer:4
# True:Law   False:Cultural
# in Law :114 and in Cultural :113
#
# Item:898 Pred:1 Answer:8
# True:Political   False:Social
# in Political :60 and in Social :58
#
# Item:902 Pred:11 Answer:1
# True:Social   False:Sport
# in Social :82 and in Sport :95
#
# Item:905 Pred:6 Answer:1
# True:Social   False:Economic
# in Social :112 and in Economic :109
#
# Item:907 Pred:6 Answer:2
# True:Scientific   False:Economic
# in Scientific :18 and in Economic :19
#
# Item:911 Pred:5 Answer:4
# True:Law   False:Religion
# in Law :51 and in Religion :68
#
# Item:915 Pred:2 Answer:1
# True:Social   False:Scientific
# in Social :163 and in Scientific :154
#
# Item:916 Pred:5 Answer:8
# True:Political   False:Religion
# in Political :395 and in Religion :377
#
# Item:919 Pred:8 Answer:4
# True:Law   False:Political
# in Law :87 and in Political :81
#
# Item:922 Pred:6 Answer:1
# True:Social   False:Economic
# in Social :135 and in Economic :129
#
# Item:927 Pred:2 Answer:1
# True:Social   False:Scientific
# in Social :90 and in Scientific :88
#
# Item:933 Pred:6 Answer:1
# True:Social   False:Economic
# in Social :19 and in Economic :19
#
# Item:934 Pred:7 Answer:1
# True:Social   False:Health
# in Social :186 and in Health :191
#
# Item:937 Pred:6 Answer:1
# True:Social   False:Economic
# in Social :32 and in Economic :32
#
# Item:945 Pred:7 Answer:3
# True:Cultural   False:Health
# in Cultural :63 and in Health :60
#
# Item:947 Pred:6 Answer:1
# True:Social   False:Economic
# in Social :46 and in Economic :43
#
# Item:953 Pred:1 Answer:2
# True:Scientific   False:Social
# in Scientific :22 and in Social :23
#
# Item:955 Pred:2 Answer:4
# True:Law   False:Scientific
# in Law :161 and in Scientific :155
#
# Item:961 Pred:9 Answer:2
# True:Scientific   False:Educational
# in Scientific :24 and in Educational :27
#
# Item:970 Pred:5 Answer:4
# True:Law   False:Religion
# in Law :20 and in Religion :20
#
# Item:971 Pred:5 Answer:8
# True:Political   False:Religion
# in Political :54 and in Religion :54
#
# Item:973 Pred:2 Answer:1
# True:Social   False:Scientific
# in Social :33 and in Scientific :33
#
# Item:990 Pred:7 Answer:2
# True:Scientific   False:Health
# in Scientific :48 and in Health :38
#
# Item:1011 Pred:1 Answer:8
# True:Political   False:Social
# in Political :54 and in Social :57
#
# Item:1016 Pred:11 Answer:1
# True:Social   False:Sport
# in Social :157 and in Sport :158
#
# Item:1019 Pred:4 Answer:8
# True:Political   False:Law
# in Political :172 and in Law :187
#
# Item:1027 Pred:1 Answer:6
# True:Economic   False:Social
# in Economic :193 and in Social :202
#
# Item:1033 Pred:4 Answer:1
# True:Social   False:Law
# in Social :39 and in Law :43
#
# Item:1040 Pred:3 Answer:1
# True:Social   False:Cultural
# in Social :80 and in Cultural :86
#
# Item:1054 Pred:1 Answer:5
# True:Religion   False:Social
# in Religion :30 and in Social :30
#
# Item:1066 Pred:4 Answer:6
# True:Economic   False:Law
# in Economic :97 and in Law :102
#
# Item:1074 Pred:3 Answer:1
# True:Social   False:Cultural
# in Social :110 and in Cultural :117
#
# Item:1080 Pred:4 Answer:6
# True:Economic   False:Law
# in Economic :157 and in Law :160
#
# Item:1081 Pred:9 Answer:2
# True:Scientific   False:Educational
# in Scientific :255 and in Educational :266
#
# Item:1083 Pred:7 Answer:1
# True:Social   False:Health
# in Social :97 and in Health :101
#
# Item:1085 Pred:1 Answer:8
# True:Political   False:Social
# in Political :174 and in Social :159
#
# Item:1087 Pred:5 Answer:3
# True:Cultural   False:Religion
# in Cultural :178 and in Religion :202
#
# Item:1097 Pred:9 Answer:1
# True:Social   False:Educational
# in Social :137 and in Educational :153
#
# Item:1098 Pred:1 Answer:8
# True:Political   False:Social
# in Political :72 and in Social :74
#
# Item:1099 Pred:8 Answer:5
# True:Religion   False:Political
# in Religion :99 and in Political :107
#
# Item:1104 Pred:1 Answer:8
# True:Political   False:Social
# in Political :146 and in Social :147
#
# Item:1121 Pred:8 Answer:1
# True:Social   False:Political
# in Social :73 and in Political :67
#
# Item:1123 Pred:2 Answer:1
# True:Social   False:Scientific
# in Social :83 and in Scientific :76
#
# Item:1124 Pred:3 Answer:6
# True:Economic   False:Cultural
# in Economic :25 and in Cultural :23
#
# Item:1128 Pred:9 Answer:1
# True:Social   False:Educational
# in Social :75 and in Educational :77
#
# Item:1129 Pred:1 Answer:3
# True:Cultural   False:Social
# in Cultural :36 and in Social :36
#
# Item:1138 Pred:4 Answer:1
# True:Social   False:Law
# in Social :45 and in Law :58
#
# Item:1140 Pred:6 Answer:1
# True:Social   False:Economic
# in Social :30 and in Economic :32
#
# Item:1142 Pred:1 Answer:5
# True:Religion   False:Social
# in Religion :35 and in Social :35
#
# Item:1145 Pred:9 Answer:2
# True:Scientific   False:Educational
# in Scientific :182 and in Educational :184
#
# Item:1151 Pred:4 Answer:8
# True:Political   False:Law
# in Political :66 and in Law :69
#
# Item:1162 Pred:6 Answer:1
# True:Social   False:Economic
# in Social :162 and in Economic :155
#
# Item:1166 Pred:2 Answer:9
# True:Educational   False:Scientific
# in Educational :32 and in Scientific :31
#
# Item:1172 Pred:9 Answer:4
# True:Law   False:Educational
# in Law :53 and in Educational :51
# Item:1193 Pred:7 Answer:1
# True:Social   False:Health
# in Social :127 and in Health :123
#
# Item:1196 Pred:2 Answer:9
# True:Educational   False:Scientific
# in Educational :85 and in Scientific :84
#
# Item:1197 Pred:9 Answer:11
# True:Sport   False:Educational
# in Sport :49 and in Educational :50
#
# Item:1198 Pred:9 Answer:2
# True:Scientific   False:Educational
# in Scientific :37 and in Educational :37
#
# Item:1201 Pred:9 Answer:8
# True:Political   False:Educational
# in Political :53 and in Educational :53
#
# Item:1202 Pred:2 Answer:7
# True:Health   False:Scientific
# in Health :81 and in Scientific :91
#
# Item:1211 Pred:7 Answer:5
# True:Religion   False:Health
# in Religion :41 and in Health :41
#
# Item:1216 Pred:5 Answer:6
# True:Economic   False:Religion
# in Economic :97 and in Religion :96
#
# Item:1221 Pred:8 Answer:4
# True:Law   False:Political
# in Law :101 and in Political :98
#
# Item:1233 Pred:5 Answer:6
# True:Economic   False:Religion
# in Economic :59 and in Religion :59
#
# Item:1235 Pred:9 Answer:6
# True:Economic   False:Educational
# in Economic :117 and in Educational :119
#
# Item:1237 Pred:9 Answer:2
# True:Scientific   False:Educational
# in Scientific :172 and in Educational :184
#
# Item:1239 Pred:5 Answer:2
# True:Scientific   False:Religion
# in Scientific :115 and in Religion :117
#
# Item:1240 Pred:1 Answer:4
# True:Law   False:Social
# in Law :124 and in Social :120
#
# Item:1241 Pred:9 Answer:8
# True:Political   False:Educational
# in Political :62 and in Educational :61
#
# Item:1250 Pred:9 Answer:11
# True:Sport   False:Educational
# in Sport :4 and in Educational :4
#
# Item:1252 Pred:8 Answer:1
# True:Social   False:Political
# in Social :50 and in Political :49
#
# Item:1255 Pred:2 Answer:9
# True:Educational   False:Scientific
# in Educational :60 and in Scientific :57
#
# Item:1261 Pred:6 Answer:2
# True:Scientific   False:Economic
# in Scientific :45 and in Economic :49
#
# Item:1263 Pred:9 Answer:8
# True:Political   False:Educational
# in Political :0 and in Educational :0
#
# Item:1264 Pred:9 Answer:11
# True:Sport   False:Educational
# in Sport :351 and in Educational :354
#
# Item:1266 Pred:8 Answer:4
# True:Law   False:Political
# in Law :95 and in Political :96
#
# Item:1271 Pred:5 Answer:6
# True:Economic   False:Religion
# in Economic :45 and in Religion :46
#
# Item:1279 Pred:7 Answer:2
# True:Scientific   False:Health
# in Scientific :40 and in Health :35
#
# Item:1285 Pred:8 Answer:4
# True:Law   False:Political
# in Law :52 and in Political :53
#
# Item:1289 Pred:1 Answer:8
# True:Political   False:Social
# in Political :113 and in Social :110
#
# Item:1295 Pred:3 Answer:2
# True:Scientific   False:Cultural
# in Scientific :62 and in Cultural :65
#
# Item:1302 Pred:7 Answer:9
# True:Educational   False:Health
# in Educational :120 and in Health :113
#
# Item:1303 Pred:1 Answer:7
# True:Health   False:Social
# in Health :46 and in Social :43
#
# Item:1310 Pred:6 Answer:1
# True:Social   False:Economic
# in Social :85 and in Economic :84
#
# Item:1319 Pred:4 Answer:6
# True:Economic   False:Law
# in Economic :83 and in Law :84
#
# Item:1325 Pred:3 Answer:11
# True:Sport   False:Cultural
# in Sport :43 and in Cultural :40
#
# Item:1329 Pred:9 Answer:3
# True:Cultural   False:Educational
# in Cultural :18 and in Educational :18
#
# Item:1333 Pred:6 Answer:2
# True:Scientific   False:Economic
# in Scientific :59 and in Economic :60
#
# Item:1334 Pred:6 Answer:9
# True:Educational   False:Economic
# in Educational :53 and in Economic :54
#
# Item:1339 Pred:8 Answer:2
# True:Scientific   False:Political
# in Scientific :124 and in Political :128
#
# Item:1344 Pred:6 Answer:8
# True:Political   False:Economic
# in Political :55 and in Economic :59
#
# Item:1360 Pred:5 Answer:4
# True:Law   False:Religion
# in Law :43 and in Religion :47
#
# Item:1361 Pred:7 Answer:5
# True:Religion   False:Health
# in Religion :149 and in Health :146
#
# Item:1363 Pred:1 Answer:3
# True:Cultural   False:Social
# in Cultural :33 and in Social :33
#
# Item:1384 Pred:8 Answer:6
# True:Economic   False:Political
# in Economic :70 and in Political :63
#
# Item:1390 Pred:3 Answer:1
# True:Social   False:Cultural
# in Social :25 and in Cultural :23
#
# Item:1392 Pred:9 Answer:2
# True:Scientific   False:Educational
# in Scientific :5 and in Educational :5
#
# Item:1404 Pred:9 Answer:2
# True:Scientific   False:Educational
# in Scientific :12 and in Educational :13
#
# Item:1416 Pred:9 Answer:1
# True:Social   False:Educational
# in Social :0 and in Educational :0
#
# Item:1418 Pred:9 Answer:1
# True:Social   False:Educational
# in Social :105 and in Educational :105
#
# Item:1423 Pred:7 Answer:2
# True:Scientific   False:Health
# in Scientific :116 and in Health :106
#
# Item:1426 Pred:8 Answer:7
# True:Health   False:Political
# in Health :69 and in Political :63
#
# Item:1428 Pred:4 Answer:8
# True:Political   False:Law
# in Political :284 and in Law :306
#
# Item:1429 Pred:6 Answer:1
# True:Social   False:Economic
# in Social :21 and in Economic :20
#
# Item:1432 Pred:2 Answer:7
# True:Health   False:Scientific
# in Health :118 and in Scientific :127
#
# Item:1435 Pred:5 Answer:1
# True:Social   False:Religion
# in Social :60 and in Religion :73
#
# Item:1439 Pred:2 Answer:7
# True:Health   False:Scientific
# in Health :73 and in Scientific :79
#
# Item:1441 Pred:3 Answer:1
# True:Social   False:Cultural
# in Social :45 and in Cultural :44
#
# Item:1442 Pred:9 Answer:2
# True:Scientific   False:Educational
# in Scientific :23 and in Educational :23
#
# Item:1446 Pred:9 Answer:1
# True:Social   False:Educational
# in Social :56 and in Educational :57
#
# Item:1448 Pred:6 Answer:1
# True:Social   False:Economic
# in Social :62 and in Economic :62
#
# Item:1449 Pred:7 Answer:2
# True:Scientific   False:Health
# in Scientific :160 and in Health :146
#
# Item:1453 Pred:2 Answer:8
# True:Political   False:Scientific
# in Political :54 and in Scientific :58
#
# Item:1472 Pred:1 Answer:11
# True:Sport   False:Social
# in Sport :39 and in Social :37
#
# Item:1482 Pred:8 Answer:4
# True:Law   False:Political
# in Law :39 and in Political :37
#
# Item:1484 Pred:1 Answer:2
# True:Scientific   False:Social
# in Scientific :17 and in Social :21
#
# Item:1488 Pred:6 Answer:1
# True:Social   False:Economic
# in Social :47 and in Economic :47
#
# Item:1492 Pred:7 Answer:2
# True:Scientific   False:Health
# in Scientific :73 and in Health :62
#
# Item:1511 Pred:5 Answer:1
# True:Social   False:Religion
# in Social :82 and in Religion :98
#
# Item:1512 Pred:2 Answer:7
# True:Health   False:Scientific
# in Health :126 and in Scientific :131
#
# Item:1523 Pred:9 Answer:2
# True:Scientific   False:Educational
# in Scientific :61 and in Educational :64
#
# Item:1530 Pred:9 Answer:11
# True:Sport   False:Educational
# in Sport :41 and in Educational :39
#
# Item:1532 Pred:2 Answer:1
# True:Social   False:Scientific
# in Social :45 and in Scientific :48
#
# Item:1537 Pred:1 Answer:6
# True:Economic   False:Social
# in Economic :35 and in Social :36
#
# Item:1544 Pred:1 Answer:9
# True:Educational   False:Social
# in Educational :344 and in Social :334
#
# Item:1547 Pred:7 Answer:11
# True:Sport   False:Health
# in Sport :22 and in Health :19
#
# Item:1557 Pred:7 Answer:9
# True:Educational   False:Health
# in Educational :116 and in Health :109
#
# Item:1562 Pred:7 Answer:2
# True:Scientific   False:Health
# in Scientific :99 and in Health :81
#
# Item:1565 Pred:2 Answer:7
# True:Health   False:Scientific
# in Health :69 and in Scientific :68
#
# Item:1569 Pred:9 Answer:1
# True:Social   False:Educational
# in Social :74 and in Educational :74
#
# Item:1578 Pred:1 Answer:9
# True:Educational   False:Social
# in Educational :41 and in Social :40
#
# Item:1591 Pred:3 Answer:1
# True:Social   False:Cultural
# in Social :26 and in Cultural :26
#
# Item:1592 Pred:9 Answer:8
# True:Political   False:Educational
# in Political :66 and in Educational :71
#
# Item:1596 Pred:2 Answer:3
# True:Cultural   False:Scientific
# in Cultural :48 and in Scientific :45
#
# Item:1614 Pred:9 Answer:4
# True:Law   False:Educational
# in Law :73 and in Educational :72
#
# Item:1618 Pred:8 Answer:1
# True:Social   False:Political
# in Social :145 and in Political :158
#
# Item:1621 Pred:7 Answer:1
# True:Social   False:Health
# in Social :198 and in Health :205
#
# Item:1622 Pred:7 Answer:2
# True:Scientific   False:Health
# in Scientific :81 and in Health :72
#
# Item:1625 Pred:3 Answer:1
# True:Social   False:Cultural
# in Social :31 and in Cultural :33
#
# Item:1630 Pred:8 Answer:1
# True:Social   False:Political
# in Social :59 and in Political :55
#
# Item:1635 Pred:6 Answer:2
# True:Scientific   False:Economic
# in Scientific :172 and in Economic :182
#
# Item:1642 Pred:8 Answer:6
# True:Economic   False:Political
# in Economic :107 and in Political :102
#
# Item:1643 Pred:8 Answer:1
# True:Social   False:Political
# in Social :197 and in Political :182
#
# Item:1646 Pred:7 Answer:9
# True:Educational   False:Health
# in Educational :99 and in Health :98
#
# Item:1650 Pred:1 Answer:2
# True:Scientific   False:Social
# in Scientific :53 and in Social :54
#
# Item:1656 Pred:9 Answer:1
# True:Social   False:Educational
# in Social :104 and in Educational :108
#
# Item:1657 Pred:9 Answer:1
# True:Social   False:Educational
# in Social :91 and in Educational :98
#
# Item:1660 Pred:8 Answer:11
# True:Sport   False:Political
# in Sport :102 and in Political :96
#
# Item:1666 Pred:4 Answer:2
# True:Scientific   False:Law
# in Scientific :181 and in Law :188
#
# Item:1684 Pred:9 Answer:7
# True:Health   False:Educational
# in Health :58 and in Educational :64
#
# Item:1689 Pred:1 Answer:6
# True:Economic   False:Social
# in Economic :131 and in Social :132
#
# Item:1690 Pred:4 Answer:6
# True:Economic   False:Law
# in Economic :100 and in Law :100
#
# Item:1691 Pred:1 Answer:6
# True:Economic   False:Social
# in Economic :42 and in Social :44
#
# Item:1694 Pred:8 Answer:1
# True:Social   False:Political
# in Social :269 and in Political :278
#
# Item:1699 Pred:9 Answer:6
# True:Economic   False:Educational
# in Economic :30 and in Educational :30
#
# Item:1702 Pred:3 Answer:8
# True:Political   False:Cultural
# in Political :20 and in Cultural :19
#
# Item:1704 Pred:1 Answer:6
# True:Economic   False:Social
# in Economic :51 and in Social :54
#
# Item:1706 Pred:3 Answer:1
# True:Social   False:Cultural
# in Social :43 and in Cultural :45
# Item:1718 Pred:8 Answer:6
# True:Economic   False:Political
# in Economic :226 and in Political :220
#
# Item:1722 Pred:3 Answer:2
# True:Scientific   False:Cultural
# in Scientific :177 and in Cultural :181
#
# Item:1735 Pred:5 Answer:6
# True:Economic   False:Religion
# in Economic :25 and in Religion :28
#
# Item:1738 Pred:6 Answer:8
# True:Political   False:Economic
# in Political :42 and in Economic :42
#
# Item:1742 Pred:8 Answer:4
# True:Law   False:Political
# in Law :62 and in Political :60
#
# Item:1756 Pred:8 Answer:1
# True:Social   False:Political
# in Social :476 and in Political :483
#
# Item:1761 Pred:9 Answer:4
# True:Law   False:Educational
# in Law :113 and in Educational :119
#
# Item:1774 Pred:3 Answer:1
# True:Social   False:Cultural
# in Social :21 and in Cultural :21
#
# Item:1776 Pred:7 Answer:2
# True:Scientific   False:Health
# in Scientific :29 and in Health :17
#
# Item:1783 Pred:7 Answer:2
# True:Scientific   False:Health
# in Scientific :108 and in Health :90
#
# Item:1787 Pred:9 Answer:1
# True:Social   False:Educational
# in Social :79 and in Educational :83
#
# Item:1805 Pred:8 Answer:6
# True:Economic   False:Political
# in Economic :66 and in Political :72
#
# Item:1807 Pred:4 Answer:2
# True:Scientific   False:Law
# in Scientific :100 and in Law :104
#
# Item:1810 Pred:9 Answer:7
# True:Health   False:Educational
# in Health :113 and in Educational :118
#
# Item:1811 Pred:5 Answer:1
# True:Social   False:Religion
# in Social :19 and in Religion :20
#
# Item:1829 Pred:3 Answer:1
# True:Social   False:Cultural
# in Social :20 and in Cultural :20
#
# Item:1830 Pred:4 Answer:11
# True:Sport   False:Law
# in Sport :348 and in Law :335
#
# Item:1836 Pred:6 Answer:3
# True:Cultural   False:Economic
# in Cultural :41 and in Economic :38
#
# Item:1837 Pred:7 Answer:2
# True:Scientific   False:Health
# in Scientific :74 and in Health :67
#
# Item:1838 Pred:6 Answer:8
# True:Political   False:Economic
# in Political :35 and in Economic :35
#
# Item:1841 Pred:6 Answer:1
# True:Social   False:Economic
# in Social :36 and in Economic :37
#
# Item:1843 Pred:9 Answer:7
# True:Health   False:Educational
# in Health :79 and in Educational :85
#
# Item:1845 Pred:6 Answer:1
# True:Social   False:Economic
# in Social :127 and in Economic :124
#
# Item:1847 Pred:9 Answer:7
# True:Health   False:Educational
# in Health :72 and in Educational :71
#
# Item:1853 Pred:9 Answer:2
# True:Scientific   False:Educational
# in Scientific :73 and in Educational :74
#
# Item:1856 Pred:9 Answer:1
# True:Social   False:Educational
# in Social :63 and in Educational :64
#
# Item:1858 Pred:7 Answer:8
# True:Political   False:Health
# in Political :52 and in Health :53
#
# Item:1860 Pred:8 Answer:9
# True:Educational   False:Political
# in Educational :118 and in Political :110
#
# Item:1861 Pred:5 Answer:4
# True:Law   False:Religion
# in Law :56 and in Religion :58
#
# Item:1864 Pred:2 Answer:3
# True:Cultural   False:Scientific
# in Cultural :46 and in Scientific :45
#
# Item:1866 Pred:3 Answer:1
# True:Social   False:Cultural
# in Social :16 and in Cultural :18
#
# Item:1877 Pred:2 Answer:6
# True:Economic   False:Scientific
# in Economic :42 and in Scientific :38
#
# Item:1885 Pred:2 Answer:6
# True:Economic   False:Scientific
# in Economic :288 and in Scientific :288
#
# Item:1890 Pred:6 Answer:1
# True:Social   False:Economic
# in Social :117 and in Economic :117
#
# Item:1895 Pred:6 Answer:1
# True:Social   False:Economic
# in Social :61 and in Economic :59
#
# Item:1897 Pred:6 Answer:8
# True:Political   False:Economic
# in Political :97 and in Economic :100
#
# Item:1902 Pred:3 Answer:8
# True:Political   False:Cultural
# in Political :13 and in Cultural :14
#
# Item:1904 Pred:9 Answer:8
# True:Political   False:Educational
# in Political :4 and in Educational :4
#
# Item:1912 Pred:9 Answer:1
# True:Social   False:Educational
# in Social :33 and in Educational :33
#
# Item:1915 Pred:9 Answer:2
# True:Scientific   False:Educational
# in Scientific :66 and in Educational :68
#
# Item:1917 Pred:1 Answer:8
# True:Political   False:Social
# in Political :45 and in Social :43
#
# Item:1921 Pred:9 Answer:4
# True:Law   False:Educational
# in Law :25 and in Educational :26
#
# Item:1923 Pred:3 Answer:8
# True:Political   False:Cultural
# in Political :108 and in Cultural :103
#
# Item:1925 Pred:4 Answer:8
# True:Political   False:Law
# in Political :55 and in Law :66
#
# Item:1930 Pred:3 Answer:4
# True:Law   False:Cultural
# in Law :67 and in Cultural :66
#
# Item:1933 Pred:9 Answer:2
# True:Scientific   False:Educational
# in Scientific :48 and in Educational :51
#
# Item:1935 Pred:4 Answer:8
# True:Political   False:Law
# in Political :126 and in Law :126
#
# Item:1942 Pred:1 Answer:6
# True:Economic   False:Social
# in Economic :21 and in Social :24
#
# Item:1946 Pred:9 Answer:6
# True:Economic   False:Educational
# in Economic :120 and in Educational :121
#
# Item:1948 Pred:7 Answer:11
# True:Sport   False:Health
# in Sport :95 and in Health :96
#
# Item:1949 Pred:3 Answer:1
# True:Social   False:Cultural
# in Social :190 and in Cultural :186
#
# Item:1951 Pred:9 Answer:2
# True:Scientific   False:Educational
# in Scientific :106 and in Educational :107
#
# Item:1952 Pred:4 Answer:7
# True:Health   False:Law
# in Health :64 and in Law :63
#
# Item:1955 Pred:5 Answer:6
# True:Economic   False:Religion
# in Economic :40 and in Religion :41
#
# Item:1956 Pred:5 Answer:1
# True:Social   False:Religion
# in Social :68 and in Religion :70
#
# Item:1966 Pred:7 Answer:2
# True:Scientific   False:Health
# in Scientific :56 and in Health :45
#
# Item:1984 Pred:1 Answer:3
# True:Cultural   False:Social
# in Cultural :120 and in Social :109
#
# Item:1986 Pred:7 Answer:1
# True:Social   False:Health
# in Social :56 and in Health :57
#
# Item:1987 Pred:6 Answer:3
# True:Cultural   False:Economic
# in Cultural :91 and in Economic :92
#
# Item:1996 Pred:7 Answer:1
# True:Social   False:Health
# in Social :82 and in Health :80
#
# Item:2000 Pred:8 Answer:5
# True:Religion   False:Political
# in Religion :89 and in Political :93
#
# Item:2004 Pred:7 Answer:1
# True:Social   False:Health
# in Social :64 and in Health :69
#
# Item:2011 Pred:5 Answer:6
# True:Economic   False:Religion
# in Economic :32 and in Religion :37
#
# Item:2013 Pred:9 Answer:7
# True:Health   False:Educational
# in Health :88 and in Educational :91
#
# Item:2017 Pred:9 Answer:2
# True:Scientific   False:Educational
# in Scientific :17 and in Educational :18
#
# Item:2023 Pred:3 Answer:1
# True:Social   False:Cultural
# in Social :177 and in Cultural :190
#
# Item:2031 Pred:6 Answer:1
# True:Social   False:Economic
# in Social :51 and in Economic :49
#
# Item:2032 Pred:7 Answer:2
# True:Scientific   False:Health
# in Scientific :111 and in Health :108
#
# Item:2034 Pred:9 Answer:2
# True:Scientific   False:Educational
# in Scientific :49 and in Educational :49
#
# Item:2035 Pred:9 Answer:1
# True:Social   False:Educational
# in Social :115 and in Educational :117
#
# Item:2036 Pred:1 Answer:5
# True:Religion   False:Social
# in Religion :64 and in Social :61
#
# Item:2040 Pred:6 Answer:1
# True:Social   False:Economic
# in Social :111 and in Economic :108
#
# Item:2041 Pred:3 Answer:4
# True:Law   False:Cultural
# in Law :128 and in Cultural :113
#
# Item:2049 Pred:6 Answer:1
# True:Social   False:Economic
# in Social :67 and in Economic :67
#
# Item:2051 Pred:5 Answer:6
# True:Economic   False:Religion
# in Economic :51 and in Religion :51
#
# Item:2057 Pred:8 Answer:6
# True:Economic   False:Political
# in Economic :118 and in Political :114
#
# Item:2060 Pred:2 Answer:1
# True:Social   False:Scientific
# in Social :47 and in Scientific :45
#
# Item:2064 Pred:7 Answer:1
# True:Social   False:Health
# in Social :72 and in Health :77
#
# Item:2072 Pred:3 Answer:8
# True:Political   False:Cultural
# in Political :28 and in Cultural :28
#
# Item:2077 Pred:9 Answer:8
# True:Political   False:Educational
# in Political :73 and in Educational :77
#
# Item:2081 Pred:1 Answer:7
# True:Health   False:Social
# in Health :89 and in Social :89
#
# Item:2087 Pred:5 Answer:4
# True:Law   False:Religion
# in Law :55 and in Religion :62
#
# Item:2098 Pred:2 Answer:9
# True:Educational   False:Scientific
# in Educational :199 and in Scientific :183
#
# Item:2106 Pred:3 Answer:1
# True:Social   False:Cultural
# in Social :77 and in Cultural :87
#
# Item:2111 Pred:8 Answer:9
# True:Educational   False:Political
# in Educational :74 and in Political :67
#
# Item:2112 Pred:7 Answer:2
# True:Scientific   False:Health
# in Scientific :40 and in Health :40
#
# Item:2113 Pred:4 Answer:8
# True:Political   False:Law
# in Political :189 and in Law :199
#
# Item:2120 Pred:9 Answer:1
# True:Social   False:Educational
# in Social :143 and in Educational :139
#
# Item:2121 Pred:2 Answer:1
# True:Social   False:Scientific
# in Social :121 and in Scientific :118
#
# Item:2122 Pred:1 Answer:9
# True:Educational   False:Social
# in Educational :157 and in Social :160
#
# Item:2126 Pred:3 Answer:1
# True:Social   False:Cultural
# in Social :62 and in Cultural :63
#
# Item:2127 Pred:9 Answer:8
# True:Political   False:Educational
# in Political :32 and in Educational :31
#
# Item:2134 Pred:4 Answer:1
# True:Social   False:Law
# in Social :62 and in Law :72
#
# Item:2147 Pred:9 Answer:7
# True:Health   False:Educational
# in Health :37 and in Educational :36
#
# Item:2152 Pred:5 Answer:4
# True:Law   False:Religion
# in Law :43 and in Religion :51
#
# Item:2156 Pred:5 Answer:6
# True:Economic   False:Religion
# in Economic :81 and in Religion :82
# Item:2162 Pred:7 Answer:2
# True:Scientific   False:Health
# in Scientific :80 and in Health :80
#
# Item:2163 Pred:1 Answer:6
# True:Economic   False:Social
# in Economic :100 and in Social :105
#
# Item:2175 Pred:11 Answer:1
# True:Social   False:Sport
# in Social :99 and in Sport :113
#
# Item:2177 Pred:9 Answer:2
# True:Scientific   False:Educational
# in Scientific :48 and in Educational :50
#
# Item:2185 Pred:5 Answer:8
# True:Political   False:Religion
# in Political :177 and in Religion :182
#
# Item:2189 Pred:2 Answer:3
# True:Cultural   False:Scientific
# in Cultural :78 and in Scientific :87
#
# Item:2193 Pred:5 Answer:6
# True:Economic   False:Religion
# in Economic :60 and in Religion :59
#
# Item:2208 Pred:4 Answer:2
# True:Scientific   False:Law
# in Scientific :73 and in Law :78
#
# Item:2210 Pred:5 Answer:3
# True:Cultural   False:Religion
# in Cultural :49 and in Religion :53
#
# Item:2214 Pred:3 Answer:6
# True:Economic   False:Cultural
# in Economic :39 and in Cultural :37
#
# Item:2219 Pred:2 Answer:3
# True:Cultural   False:Scientific
# in Cultural :45 and in Scientific :46
#
# Item:2222 Pred:3 Answer:2
# True:Scientific   False:Cultural
# in Scientific :130 and in Cultural :135
#
# Item:2232 Pred:9 Answer:2
# True:Scientific   False:Educational
# in Scientific :108 and in Educational :112
#
# Item:2233 Pred:8 Answer:6
# True:Economic   False:Political
# in Economic :83 and in Political :83
#
# Item:2237 Pred:3 Answer:2
# True:Scientific   False:Cultural
# in Scientific :86 and in Cultural :87
#
# Item:2249 Pred:7 Answer:1
# True:Social   False:Health
# in Social :34 and in Health :41
#
# Item:2253 Pred:9 Answer:7
# True:Health   False:Educational
# in Health :61 and in Educational :61
#
# Item:2259 Pred:6 Answer:1
# True:Social   False:Economic
# in Social :72 and in Economic :71
#
# Item:2263 Pred:1 Answer:7
# True:Health   False:Social
# in Health :31 and in Social :33
#
# Item:2265 Pred:4 Answer:1
# True:Social   False:Law
# in Social :354 and in Law :393
#
# Item:2267 Pred:5 Answer:3
# True:Cultural   False:Religion
# in Cultural :167 and in Religion :184
#
# Item:2270 Pred:9 Answer:3
# True:Cultural   False:Educational
# in Cultural :40 and in Educational :40
#
# Item:2280 Pred:6 Answer:8
# True:Political   False:Economic
# in Political :81 and in Economic :78
#
# Item:2283 Pred:8 Answer:1
# True:Social   False:Political
# in Social :110 and in Political :108
#
# Item:2286 Pred:7 Answer:11
# True:Sport   False:Health
# in Sport :165 and in Health :154
#
# Item:2290 Pred:2 Answer:1
# True:Social   False:Scientific
# in Social :40 and in Scientific :42
#
# Item:2302 Pred:4 Answer:8
# True:Political   False:Law
# in Political :72 and in Law :74
#
# Item:2304 Pred:5 Answer:4
# True:Law   False:Religion
# in Law :88 and in Religion :96
#
# Item:2306 Pred:6 Answer:4
# True:Law   False:Economic
# in Law :89 and in Economic :91
#
# Item:2309 Pred:6 Answer:1
# True:Social   False:Economic
# in Social :110 and in Economic :108
#
# Item:2313 Pred:6 Answer:8
# True:Political   False:Economic
# in Political :92 and in Economic :93
#
# Item:2319 Pred:8 Answer:1
# True:Social   False:Political
# in Social :95 and in Political :100
#
# Item:2323 Pred:3 Answer:1
# True:Social   False:Cultural
# in Social :15 and in Cultural :15
#
# Item:2340 Pred:6 Answer:1
# True:Social   False:Economic
# in Social :63 and in Economic :59
#
# Item:2341 Pred:4 Answer:1
# True:Social   False:Law
# in Social :43 and in Law :55
#
# Item:2344 Pred:1 Answer:8
# True:Political   False:Social
# in Political :32 and in Social :28
#
# Item:2351 Pred:1 Answer:7
# True:Health   False:Social
# in Health :71 and in Social :69
#
# Item:2352 Pred:9 Answer:1
# True:Social   False:Educational
# in Social :99 and in Educational :117
#
# Item:2364 Pred:2 Answer:3
# True:Cultural   False:Scientific
# in Cultural :53 and in Scientific :53
#
# Item:2365 Pred:5 Answer:8
# True:Political   False:Religion
# in Political :64 and in Religion :65
#
# Item:2377 Pred:9 Answer:1
# True:Social   False:Educational
# in Social :24 and in Educational :24
#
# Item:2379 Pred:3 Answer:1
# True:Social   False:Cultural
# in Social :99 and in Cultural :102
#
# Item:2386 Pred:5 Answer:6
# True:Economic   False:Religion
# in Economic :189 and in Religion :181
#
# Item:2388 Pred:4 Answer:8
# True:Political   False:Law
# in Political :136 and in Law :142
#
# Item:2396 Pred:5 Answer:8
# True:Political   False:Religion
# in Political :140 and in Religion :142
#
# Item:2397 Pred:9 Answer:2
# True:Scientific   False:Educational
# in Scientific :52 and in Educational :52
#
# Item:2406 Pred:9 Answer:3
# True:Cultural   False:Educational
# in Cultural :72 and in Educational :81
#
# Item:2407 Pred:8 Answer:1
# True:Social   False:Political
# in Social :63 and in Political :67
#
# Item:2408 Pred:9 Answer:1
# True:Social   False:Educational
# in Social :31 and in Educational :32
#
# Item:2412 Pred:1 Answer:8
# True:Political   False:Social
# in Political :106 and in Social :98
#
# Item:2415 Pred:1 Answer:11
# True:Sport   False:Social
# in Sport :37 and in Social :37
#
# Item:2423 Pred:7 Answer:2
# True:Scientific   False:Health
# in Scientific :88 and in Health :78
#
# Item:2426 Pred:4 Answer:8
# True:Political   False:Law
# in Political :42 and in Law :42
#
# Item:2428 Pred:5 Answer:8
# True:Political   False:Religion
# in Political :26 and in Religion :26
#
# Item:2434 Pred:9 Answer:8
# True:Political   False:Educational
# in Political :47 and in Educational :48
#
# Item:2437 Pred:4 Answer:8
# True:Political   False:Law
# in Political :139 and in Law :141
#
# Item:2439 Pred:1 Answer:11
# True:Sport   False:Social
# in Sport :57 and in Social :56
#
# Item:2450 Pred:4 Answer:8
# True:Political   False:Law
# in Political :87 and in Law :88
#
# Item:2454 Pred:7 Answer:2
# True:Scientific   False:Health
# in Scientific :133 and in Health :123
#
# Item:2469 Pred:4 Answer:6
# True:Economic   False:Law
# in Economic :125 and in Law :130
#
# Item:2471 Pred:1 Answer:6
# True:Economic   False:Social
# in Economic :78 and in Social :82
#
# Item:2485 Pred:7 Answer:2
# True:Scientific   False:Health
# in Scientific :157 and in Health :135
#
# Item:2486 Pred:6 Answer:1
# True:Social   False:Economic
# in Social :107 and in Economic :105
#
# Item:2489 Pred:9 Answer:2
# True:Scientific   False:Educational
# in Scientific :132 and in Educational :132
#
# Item:2497 Pred:3 Answer:9
# True:Educational   False:Cultural
# in Educational :61 and in Cultural :61
#
# Item:2498 Pred:4 Answer:8
# True:Political   False:Law
# in Political :192 and in Law :192

# %%
category=['','Social','Scientific','Cultural','Law','Religion','Economic','Health','Political','Educational','History','Sport']

def test_onto(itest):
    
    #print (X_test1.loc[itest].Content)
    print ("True:{}   False:{}".format(category[Y_test1.loc[itest].Cat_Idx],category[y_pred[itest]]))
  
    doc=set(X_test1.loc[itest].Content.split(' '))

    sss=doc.intersection(ontology_dic[category[Y_test1.loc[itest].Cat_Idx]])
    sss2=doc.intersection(ontology_dic[category[y_pred[itest]]]) 
    print ("in {} :{} and in {} :{}\n".format(category[Y_test1.loc[itest].Cat_Idx],len(sss),category[y_pred[itest]],len(sss2)))

# %%
start = datetime.datetime.now()

df3=pd.DataFrame()
df3['Word']=count_vectorizer.get_feature_names()
df3['Count']=X.toarray().sum(axis=0)
df3.to_csv('test22',encoding="utf-8")
end = datetime.datetime.now()
print ("Time:{}".format(end-start))
# Out:
# Time:0:00:02.063138

# %%
Word_count=df3['Count'].value_counts()
plt.figure(figsize=(50,20))
sns.barplot(Word_count.values, Word_count.index, alpha=0.8)
plt.title(u'Word Frequency')
plt.ylabel(u'Number of Occurrences', fontsize=12)
plt.xlabel(u'Word', fontsize=12)
plt.show()
# Out:
# /anaconda2/lib/python2.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
count_vectorizer = CountVectorizer()
multinomialNB = MultinomialNB()
print(multiprocessing.cpu_count())
# Define pipeline
mn_cv_nb_pipeline = Pipeline([('vectorizer', count_vectorizer),
                             ('multinomial_nb', multinomialNB)])

# Grid search parameters
mn_cv_nb_param_grid = [
    { 
        'vectorizer__min_df': [ 1, 2, 3, 4, 5 ],
        'vectorizer__ngram_range': [ (1, 1)],
        'multinomial_nb__alpha': [ 0.0, 0.25, 0.5, 0.75, 1.0 ]
    }
]

# Perform grid search
mn_cv_nb_gs = GridSearchCV(estimator=mn_cv_nb_pipeline, param_grid=mn_cv_nb_param_grid, 
                           scoring='accuracy', cv=25, n_jobs=multiprocessing.cpu_count())

mn_cv_nb_gs.fit(X_train, Y_train)

# Create an instance of the best estimator
mn_cv_nb_best = mn_cv_nb_gs.best_estimator_
mn_cv_nb_best.fit(X_train, Y_train)

print('Best model: %s' % str(mn_cv_nb_gs.best_params_))
print('Best score: %f' % mn_cv_nb_gs.best_score_)
print('Best test accuracy: %f' % mn_cv_nb_best.score(X_test, Y_test))
# Out:
# 4
# /anaconda2/lib/python2.7/site-packages/sklearn/naive_bayes.py:472: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /anaconda2/lib/python2.7/site-packages/sklearn/naive_bayes.py:472: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /anaconda2/lib/python2.7/site-packages/sklearn/naive_bayes.py:472: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /anaconda2/lib/python2.7/site-packages/sklearn/naive_bayes.py:472: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /anaconda2/lib/python2.7/site-packages/sklearn/naive_bayes.py:472: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /anaconda2/lib/python2.7/site-packages/sklearn/naive_bayes.py:472: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /anaconda2/lib/python2.7/site-packages/sklearn/naive_bayes.py:472: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /anaconda2/lib/python2.7/site-packages/sklearn/naive_bayes.py:472: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /anaconda2/lib/python2.7/site-packages/sklearn/naive_bayes.py:472: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /anaconda2/lib/python2.7/site-packages/sklearn/naive_bayes.py:472: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /anaconda2/lib/python2.7/site-packages/sklearn/naive_bayes.py:472: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /anaconda2/lib/python2.7/site-packages/sklearn/naive_bayes.py:472: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /anaconda2/lib/python2.7/site-packages/sklearn/naive_bayes.py:472: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /anaconda2/lib/python2.7/site-packages/sklearn/naive_bayes.py:472: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /anaconda2/lib/python2.7/site-packages/sklearn/naive_bayes.py:472: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /anaconda2/lib/python2.7/site-packages/sklearn/naive_bayes.py:472: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /anaconda2/lib/python2.7/site-packages/sklearn/naive_bayes.py:472: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /anaconda2/lib/python2.7/site-packages/sklearn/naive_bayes.py:472: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /anaconda2/lib/python2.7/site-packages/sklearn/naive_bayes.py:472: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /anaconda2/lib/python2.7/site-packages/sklearn/naive_bayes.py:472: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /anaconda2/lib/python2.7/site-packages/sklearn/naive_bayes.py:472: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /anaconda2/lib/python2.7/site-packages/sklearn/naive_bayes.py:472: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /anaconda2/lib/python2.7/site-packages/sklearn/naive_bayes.py:472: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /anaconda2/lib/python2.7/site-packages/sklearn/naive_bayes.py:472: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /anaconda2/lib/python2.7/site-packages/sklearn/naive_bayes.py:472: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /anaconda2/lib/python2.7/site-packages/sklearn/naive_bayes.py:472: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /anaconda2/lib/python2.7/site-packages/sklearn/naive_bayes.py:472: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /anaconda2/lib/python2.7/site-packages/sklearn/naive_bayes.py:472: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /anaconda2/lib/python2.7/site-packages/sklearn/naive_bayes.py:472: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /anaconda2/lib/python2.7/site-packages/sklearn/naive_bayes.py:472: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /anaconda2/lib/python2.7/site-packages/sklearn/naive_bayes.py:472: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /anaconda2/lib/python2.7/site-packages/sklearn/naive_bayes.py:472: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /anaconda2/lib/python2.7/site-packages/sklearn/naive_bayes.py:472: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /anaconda2/lib/python2.7/site-packages/sklearn/naive_bayes.py:472: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /anaconda2/lib/python2.7/site-packages/sklearn/naive_bayes.py:472: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /anaconda2/lib/python2.7/site-packages/sklearn/naive_bayes.py:472: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /anaconda2/lib/python2.7/site-packages/sklearn/naive_bayes.py:472: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /anaconda2/lib/python2.7/site-packages/sklearn/naive_bayes.py:472: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /anaconda2/lib/python2.7/site-packages/sklearn/naive_bayes.py:472: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /anaconda2/lib/python2.7/site-packages/sklearn/naive_bayes.py:472: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /anaconda2/lib/python2.7/site-packages/sklearn/naive_bayes.py:472: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /anaconda2/lib/python2.7/site-packages/sklearn/naive_bayes.py:472: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /anaconda2/lib/python2.7/site-packages/sklearn/naive_bayes.py:472: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /anaconda2/lib/python2.7/site-packages/sklearn/naive_bayes.py:472: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /anaconda2/lib/python2.7/site-packages/sklearn/naive_bayes.py:472: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /anaconda2/lib/python2.7/site-packages/sklearn/naive_bayes.py:472: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /anaconda2/lib/python2.7/site-packages/sklearn/naive_bayes.py:472: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /anaconda2/lib/python2.7/site-packages/sklearn/naive_bayes.py:472: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /anaconda2/lib/python2.7/site-packages/sklearn/naive_bayes.py:472: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /anaconda2/lib/python2.7/site-packages/sklearn/naive_bayes.py:472: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /anaconda2/lib/python2.7/site-packages/sklearn/naive_bayes.py:472: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /anaconda2/lib/python2.7/site-packages/sklearn/naive_bayes.py:472: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /anaconda2/lib/python2.7/site-packages/sklearn/naive_bayes.py:472: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /anaconda2/lib/python2.7/site-packages/sklearn/naive_bayes.py:472: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /anaconda2/lib/python2.7/site-packages/sklearn/naive_bayes.py:472: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /anaconda2/lib/python2.7/site-packages/sklearn/naive_bayes.py:472: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /anaconda2/lib/python2.7/site-packages/sklearn/naive_bayes.py:472: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /anaconda2/lib/python2.7/site-packages/sklearn/naive_bayes.py:472: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /anaconda2/lib/python2.7/site-packages/sklearn/naive_bayes.py:472: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /anaconda2/lib/python2.7/site-packages/sklearn/naive_bayes.py:472: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /anaconda2/lib/python2.7/site-packages/sklearn/naive_bayes.py:472: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /anaconda2/lib/python2.7/site-packages/sklearn/naive_bayes.py:472: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /anaconda2/lib/python2.7/site-packages/sklearn/naive_bayes.py:472: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /anaconda2/lib/python2.7/site-packages/sklearn/naive_bayes.py:472: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /anaconda2/lib/python2.7/site-packages/sklearn/naive_bayes.py:472: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /anaconda2/lib/python2.7/site-packages/sklearn/naive_bayes.py:472: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /anaconda2/lib/python2.7/site-packages/sklearn/naive_bayes.py:472: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /anaconda2/lib/python2.7/site-packages/sklearn/naive_bayes.py:472: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /anaconda2/lib/python2.7/site-packages/sklearn/naive_bayes.py:472: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /anaconda2/lib/python2.7/site-packages/sklearn/naive_bayes.py:472: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /anaconda2/lib/python2.7/site-packages/sklearn/naive_bayes.py:472: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /anaconda2/lib/python2.7/site-packages/sklearn/naive_bayes.py:472: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /anaconda2/lib/python2.7/site-packages/sklearn/naive_bayes.py:472: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /anaconda2/lib/python2.7/site-packages/sklearn/naive_bayes.py:472: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /anaconda2/lib/python2.7/site-packages/sklearn/naive_bayes.py:472: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /anaconda2/lib/python2.7/site-packages/sklearn/naive_bayes.py:472: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /anaconda2/lib/python2.7/site-packages/sklearn/naive_bayes.py:472: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /anaconda2/lib/python2.7/site-packages/sklearn/naive_bayes.py:472: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /anaconda2/lib/python2.7/site-packages/sklearn/naive_bayes.py:472: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /anaconda2/lib/python2.7/site-packages/sklearn/naive_bayes.py:472: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /anaconda2/lib/python2.7/site-packages/sklearn/naive_bayes.py:472: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /anaconda2/lib/python2.7/site-packages/sklearn/naive_bayes.py:472: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /anaconda2/lib/python2.7/site-packages/sklearn/naive_bayes.py:472: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /anaconda2/lib/python2.7/site-packages/sklearn/naive_bayes.py:472: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /anaconda2/lib/python2.7/site-packages/sklearn/naive_bayes.py:472: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /anaconda2/lib/python2.7/site-packages/sklearn/naive_bayes.py:472: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /anaconda2/lib/python2.7/site-packages/sklearn/naive_bayes.py:472: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /anaconda2/lib/python2.7/site-packages/sklearn/naive_bayes.py:472: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /anaconda2/lib/python2.7/site-packages/sklearn/naive_bayes.py:472: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /anaconda2/lib/python2.7/site-packages/sklearn/naive_bayes.py:472: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /anaconda2/lib/python2.7/site-packages/sklearn/naive_bayes.py:472: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /anaconda2/lib/python2.7/site-packages/sklearn/naive_bayes.py:472: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /anaconda2/lib/python2.7/site-packages/sklearn/naive_bayes.py:472: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /anaconda2/lib/python2.7/site-packages/sklearn/naive_bayes.py:472: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /anaconda2/lib/python2.7/site-packages/sklearn/naive_bayes.py:472: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /anaconda2/lib/python2.7/site-packages/sklearn/naive_bayes.py:472: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /anaconda2/lib/python2.7/site-packages/sklearn/naive_bayes.py:472: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /anaconda2/lib/python2.7/site-packages/sklearn/naive_bayes.py:472: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /anaconda2/lib/python2.7/site-packages/sklearn/naive_bayes.py:472: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /anaconda2/lib/python2.7/site-packages/sklearn/naive_bayes.py:472: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /anaconda2/lib/python2.7/site-packages/sklearn/naive_bayes.py:472: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /anaconda2/lib/python2.7/site-packages/sklearn/naive_bayes.py:472: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /anaconda2/lib/python2.7/site-packages/sklearn/naive_bayes.py:472: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /anaconda2/lib/python2.7/site-packages/sklearn/naive_bayes.py:472: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /anaconda2/lib/python2.7/site-packages/sklearn/naive_bayes.py:472: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /anaconda2/lib/python2.7/site-packages/sklearn/naive_bayes.py:472: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /anaconda2/lib/python2.7/site-packages/sklearn/naive_bayes.py:472: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /anaconda2/lib/python2.7/site-packages/sklearn/naive_bayes.py:472: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /anaconda2/lib/python2.7/site-packages/sklearn/naive_bayes.py:472: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /anaconda2/lib/python2.7/site-packages/sklearn/naive_bayes.py:472: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /anaconda2/lib/python2.7/site-packages/sklearn/naive_bayes.py:472: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /anaconda2/lib/python2.7/site-packages/sklearn/naive_bayes.py:472: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /anaconda2/lib/python2.7/site-packages/sklearn/naive_bayes.py:472: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /anaconda2/lib/python2.7/site-packages/sklearn/naive_bayes.py:472: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /anaconda2/lib/python2.7/site-packages/sklearn/naive_bayes.py:472: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /anaconda2/lib/python2.7/site-packages/sklearn/naive_bayes.py:472: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /anaconda2/lib/python2.7/site-packages/sklearn/naive_bayes.py:472: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /anaconda2/lib/python2.7/site-packages/sklearn/naive_bayes.py:472: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /anaconda2/lib/python2.7/site-packages/sklearn/naive_bayes.py:472: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /anaconda2/lib/python2.7/site-packages/sklearn/naive_bayes.py:472: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /anaconda2/lib/python2.7/site-packages/sklearn/naive_bayes.py:472: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /anaconda2/lib/python2.7/site-packages/sklearn/naive_bayes.py:472: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /anaconda2/lib/python2.7/site-packages/sklearn/naive_bayes.py:472: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /anaconda2/lib/python2.7/site-packages/sklearn/naive_bayes.py:472: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /anaconda2/lib/python2.7/site-packages/sklearn/naive_bayes.py:472: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# Best model: {u'vectorizer__min_df': 2, u'multinomial_nb__alpha': 0.5, u'vectorizer__ngram_range': (1, 1)}
# Best score: 0.790641
# Best test accuracy: 0.788727

# %%
#TFIDF
X_train, X_test, Y_train, Y_test = train_test_split(news_data['Content'], news_data['Cat_Idx'], test_size=0.25)

tfidf_vectorizer = TfidfVectorizer(ngram_range=(1, 3))
X=tfidf_vectorizer.fit_transform(X_train)
Xtest=tfidf_vectorizer.transform(X_test)

algo = MultinomialNB(alpha=0.5)
algo.fit(X,Y_train)
y_pred=algo.predict(Xtest)
yscore=algo.score(Xtest,Y_test)
print(yscore)

plot_confusion_matrix(Y_test,y_pred)
# Out:
# 0.81

# %%
#Create tagged documents
news_tagged_documents = []

for i, document in enumerate(news_data['Content']):
    news_tagged_documents.append(TaggedDocument(document.split(' '), [i]))
# Train Doc2Vec
doc2vec_vector_size = 50

doc2vec_model = Doc2Vec(documents=news_tagged_documents, size=doc2vec_vector_size, window=3, 
                        min_count=2, iter=30, workers=multiprocessing.cpu_count())
doc2vec_model.init_sims(replace=False)

# Vectorize documents and split the whole corpus in train and test sets
news_vectors = []

for document in news_data['Content']:
    news_vectors.append(doc2vec_model.infer_vector(document.split(' ')))

d2v_X_train, d2v_X_test, d2v_Y_train, d2v_Y_test = train_test_split(news_vectors, news_data['Cat_Idx'], test_size=0.25)
# Out:
# /anaconda2/lib/python2.7/site-packages/gensim/models/doc2vec.py:566: UserWarning: The parameter `iter` is deprecated, will be removed in 4.0.0, use `epochs` instead.
#   warnings.warn("The parameter `iter` is deprecated, will be removed in 4.0.0, use `epochs` instead.")
# /anaconda2/lib/python2.7/site-packages/gensim/models/doc2vec.py:570: UserWarning: The parameter `size` is deprecated, will be removed in 4.0.0, use `vector_size` instead.
#   warnings.warn("The parameter `size` is deprecated, will be removed in 4.0.0, use `vector_size` instead.")

# %%
scaler = StandardScaler()
svc = SVC()

# Define pipeline
svc_d2v_pipeline = Pipeline([('scaler', scaler),
                             ('svc', svc)])

# Grid search parameters
svc_d2v_param_grid = [
    { 
        'svc__kernel': [ 'linear' ],
        'svc__C': [0.5, 1.0, 5.0, 10.0 ]
    },
    { 
        'svc__kernel': [ 'poly' ],
        'svc__C': [0.5, 1.0, 5.0, 10.0 ]
    },
    { 
        'svc__kernel': [ 'rbf' ],
        'svc__C': [0.5, 1.0, 5.0, 10.0 ]
    }
]
# Perform grid search
svc_d2v_gs = GridSearchCV(estimator=svc_d2v_pipeline, param_grid=svc_d2v_param_grid, 
                           scoring='accuracy', cv=25, n_jobs=multiprocessing.cpu_count())

svc_d2v_gs.fit(d2v_X_train, d2v_Y_train)

# Create an instance of the best estimator
svc_d2v_best = svc_d2v_gs.best_estimator_
svc_d2v_best.fit(d2v_X_train, d2v_Y_train)

print('Best model: %s' % str(svc_d2v_gs.best_params_))
print('Best score: %f' % svc_d2v_gs.best_score_)
svc_d2v_Y_pred = svc_d2v_best.predict(d2v_X_test)
plot_confusion_matrix(Y_test,svc_d2v_Y_pred)
# Out:
# Best model: {u'svc__kernel': u'rbf', u'svc__C': 1.0}
# Best score: 0.771067
